# %% [markdown]
# ### Results.Plotting
#
# Program for plotting results of exp3_Afterselection- action vector analysis

# %% [markdown]
# #### Adjusted random scores

# %%
import matplotlib.pyplot as plt 
   
percent_of_features=[.2,.4,.6,.8,1] 

layer1=[.00,.03,.05,.21,.12] 
layer2=[.09,.02,.30,.26,.28]
layer3=[.33,.33,.28,.28,.28]
layer4=[.27,.28,.28,.30,.28]
layer5=[.27,.27,.37,.28,.29]
layer6=[.31,.38,.32,.32,.32]
layer7=[.32,.30,.27,.38,.38]
layer8=[.31,.28,.17,.22,.22]
layer9=[.10,.10,.10,.12,.12]
    
plt.plot(percent_of_features,layer1,label='layer1')
plt.plot(percent_of_features,layer2,label='layer2')
plt.plot(percent_of_features,layer3,label='layer3')
plt.plot(percent_of_features,layer4,label='layer4')
plt.plot(percent_of_features,layer5,label='layer5')
plt.plot(percent_of_features,layer6,label='layer6')
plt.plot(percent_of_features,layer7,label='layer7')
plt.plot(percent_of_features,layer8,label='layer8')
plt.plot(percent_of_features,layer9,label='layer9')


plt.xlabel('Percetage of features used') 
plt.ylabel('Adjusted random score') 
plt.title('Adjusted random scores with perecentage of features selected') 
plt.legend(loc='upper right',bbox_to_anchor=(1.3, 1.05))
plt.show()

# %% [markdown]
# #### Mutual information base score

# %%
import matplotlib.pyplot as plt 
   
percent_of_features=[.2,.4,.6,.8,1] 

layer1=[.03,.08,.10,.24,.16] 
layer2=[.13,.06,.31,.29,.30]
layer3=[.28,.41,.25,.25,.25]
layer4=[.26,.25,.25,.30,.25]
layer5=[.26,.26,.33,.25,.30]
layer6=[.30,.36,.36,.36,.36]
layer7=[.36,.30,.25,.36,.36]
layer8=[.35,.33,.19,.24,.24]
layer9=[.12,.16,.16,.18,.18]
    
plt.plot(percent_of_features,layer1,label='layer1')
plt.plot(percent_of_features,layer2,label='layer2')
plt.plot(percent_of_features,layer3,label='layer3')
plt.plot(percent_of_features,layer4,label='layer4')
plt.plot(percent_of_features,layer5,label='layer5')
plt.plot(percent_of_features,layer6,label='layer6')
plt.plot(percent_of_features,layer7,label='layer7')
plt.plot(percent_of_features,layer8,label='layer8')
plt.plot(percent_of_features,layer9,label='layer9')


plt.xlabel('Percetage of features used') 
plt.ylabel('Mutual information base score') 
plt.title('Mutual information base score with perecentage of features selected') 
plt.legend(loc='upper right',bbox_to_anchor=(1.3, 1.05))
plt.show()

# %% [markdown]
# ##### Homogeinity score

# %%
import matplotlib.pyplot as plt 
   
percent_of_features=[.2,.4,.6,.8,1] 

layer1=[.08,.12,.15,.27,.20] 
layer2=[.17,.11,.34,.32,.33]
layer3=[.31,.41,.28,.28,.28]
layer4=[.30,.28,.28,.33,.28]
layer5=[.30,.30,.36,.28,.33]
layer6=[.33,.39,.39,.39,.39]
layer7=[.39,.33,.29,.39,.39]
layer8=[.38,.36,.23,.27,.27]
layer9=[.17,.21,.21,.22,.22]
    
plt.plot(percent_of_features,layer1,label='layer1')
plt.plot(percent_of_features,layer2,label='layer2')
plt.plot(percent_of_features,layer3,label='layer3')
plt.plot(percent_of_features,layer4,label='layer4')
plt.plot(percent_of_features,layer5,label='layer5')
plt.plot(percent_of_features,layer6,label='layer6')
plt.plot(percent_of_features,layer7,label='layer7')
plt.plot(percent_of_features,layer8,label='layer8')
plt.plot(percent_of_features,layer9,label='layer9')


plt.xlabel('Percetage of features used') 
plt.ylabel('Homogeinity score') 
plt.title('Homogeinity score with perecentage of features selected') 
plt.legend(loc='upper right',bbox_to_anchor=(1.3, 1.05))
plt.show()
