# %%
from os import listdir

# %%
from os import walk

# %%
import numpy as np

# %%
from PIL import Image

# %%
from scipy.ndimage import imread

# %%
rgb = Image.open('./reach0/0rgb.png')

# %%
rgb
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x360 at 0x2B2DFF423EB8>

# %%
imread('./reach0/0rgb.png')[:,:,:3].shape
# Out:
# (360, 640, 3)

# %%
videos = np.empty([3*5, 40, 360, 640, 3], dtype=np.float32)

# %%
videos.shape
# Out:
# (15, 40, 360, 640, 3)

# %%
dspath = './'
activity = []
vidIndex = -1
for directory in listdir(dspath): 
    if directory[0] != '.': #Each Activity
        for vid in range(5): #Each video
            vidpath = dspath+directory+'/'+str(vid)+'/'
            vidIndex += 1;
            activity.append(directory)
            for frame in range(40): #Each frame
                framepath = vidpath+str(frame)+'rgb.png'
                # print('[',vidIndex, frame, ']', directory)
                print('Loading ', framepath)
                videos[vidIndex, frame] = imread(framepath)[:,:,:3]
# Out:
# Loading  ./CreateDataSet.ipynb/0/0rgb.png
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-14-72fa39dbfde5> in <module>()
#      12                 # print('[',vidIndex, frame, ']', directory)
#      13                 print('Loading ', framepath)
# ---> 14                 videos[vidIndex, frame] = imread(framepath)[:,:,:3]
#
# /opt/conda/lib/python3.6/site-packages/scipy/ndimage/io.py in imread(fname, flatten, mode)
#      22 def imread(fname, flatten=False, mode=None):
#      23     if _have_pil:
# ---> 24         return _imread(fname, flatten, mode)
#      25     raise ImportError("Could not import the Python Imaging Library (PIL)"
#      26                       " required to load image files.  Please refer to"
#
# /opt/conda/lib/python3.6/site-packages/scipy/misc/pilutil.py in imread(name, flatten, mode)
#     154     """
#     155
# --> 156     im = Image.open(name)
#     157     return fromimage(im, flatten=flatten, mode=mode)
#     158
#
# /opt/conda/lib/python3.6/site-packages/PIL/Image.py in open(fp, mode)
#    2408
#    2409     if filename:
# -> 2410         fp = builtins.open(filename, "rb")
#    2411         exclusive_fp = True
#    2412
#
# NotADirectoryError: [Errno 20] Not a directory: './CreateDataSet.ipynb/0/0rgb.png'

# %%
videos.shape
# Out:
# (15, 40, 360, 640, 3)

# %%
activity
# Out:
# ['CreateDataSet.ipynb']

# %%
dataset = {'videos':videos, 'activities':activity}

# %%
dataset['videos'].shape
# Out:
# (15, 40, 360, 640, 3)

# %%
dataset['activities']
# Out:
# ['CreateDataSet.ipynb']

# %%
Image.fromarray(videos[10,25].astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=640x360 at 0x2B2DFF7F1630>

# %%
np.save('videos.npy',videos)
