# %% [markdown]
# #### Description
#
# Program for plotting results of experiment: higher pretrained acc vs ARI score

# %%
import matplotlib.pyplot as plt 
plt.rcParams.update({'font.size': 30})
plt.rcParams["font.family"] = "serif"
plt.rcParams['axes.labelweight'] = 'bold'
plt.rcParams["figure.figsize"] = [16, 12]
   
percent_of_features=[60.72,70.23,77.05,79.52,80.62] 

#layer1=[.00,.03,.05,.21,.12] 
#layer2=[.09,.02,.30,.26,.28]
#layer3=[.33,.33,.28,.28,.28]
#layer4=[.27,.28,.28,.30,.28]
layer5=[.26,
.33,
.33,
.34,
.34,
]
layer6=[.34,
.23,
.33,
.36,
.35,
]
#layer7=[.32,.30,.27,.38,.38]
#layer8=[.31,.28,.17,.22,.22]
#layer9=[.10,.10,.10,.12,.12]
    
#plt.plot(percent_of_features,layer1,label='layer1')
#plt.plot(percent_of_features,layer2,label='layer2')
#plt.plot(percent_of_features,layer3,label='layer3')
#plt.plot(percent_of_features,layer4,label='layer4')
plt.plot(percent_of_features,layer5,label='pool5',marker='o')
plt.plot(percent_of_features,layer6,label='fc6',marker='o')
#plt.plot(percent_of_features,layer7,label='layer7')
#plt.plot(percent_of_features,layer8,label='layer8')
#plt.plot(percent_of_features,layer9,label='layer9')


plt.xlabel('Pre-training accuracy') 
plt.ylabel('ARI score') 
plt.legend(loc='upper right',bbox_to_anchor=(1.3, 1.05))
plt.xticks([60,65,70,75,80])  

fontsize_annotate=25
#plt.annotate('[1638]', xy=(.21,.35), textcoords='data',fontsize=fontsize_annotate)
#plt.annotate('[3276]', xy=(.41,.32), textcoords='data',fontsize=fontsize_annotate)
#plt.annotate('[4915]', xy=(.61,.29), textcoords='data',fontsize=fontsize_annotate)
#plt.annotate('[6553]', xy=(.81,.31), textcoords='data',fontsize=fontsize_annotate)
#plt.annotate('[8192]', xy=(1.01,.26), textcoords='data',fontsize=fontsize_annotate)

#plt.annotate('[819]', xy=(.21,.39), textcoords='data',fontsize=fontsize_annotate)
#plt.annotate('[1638]', xy=(.41,.34), textcoords='data',fontsize=fontsize_annotate)
#plt.annotate('[2457]', xy=(.61,.34), textcoords='data',fontsize=fontsize_annotate)
#plt.annotate('[3276]', xy=(.81,.34), textcoords='data',fontsize=fontsize_annotate)
#plt.annotate('[4096]', xy=(1.01,.34), textcoords='data',fontsize=fontsize_annotate)

plt.show()
