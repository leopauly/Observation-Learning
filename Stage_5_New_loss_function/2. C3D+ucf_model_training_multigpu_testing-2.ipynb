# %%
### 2. C3D+ucf_model_training_multigpu_training
# Author : @leopauly | cnlp@leeds.ac.uk <br>
# Description : Training the C3D model using UCF 101 action recognition dataset- Testing Phase

print('Started running the program..!',flush=True)
## Imports
from keras.models import Sequential
import random
import numpy as np
from PIL import Image
from os import listdir
from scipy.ndimage import imread
import keras
import tensorflow as tf
from tensorflow.python.client import device_lib
from keras import backend as K
import datetime
import time
import os 
from datetime import timedelta


# Custom scripts
import lscript as lsp
import modelling as md
#from DataSet.DataSet import DataSet
import dataset as dset
import ucf101_dataset as ucf

print('Loaded libraries...!!',flush=True)
# Out:
# Started running the program..!
# Using TensorFlow backend.
# Loaded libraries...!!

# %%
height=112 
width=112 
channel=3
cluster_length=16
nb_classes=101

lr_rate=.001
next_batch_start=0
batch_size=8
batch_size_test=16
total_train_videos=9991
memory_batch_size_train=50
memory_batch_size_test=3329
iterations= 10 # (int(total_train_videos/memory_batch_size_train)) #10001
custom_global_step=0
LOG_DIR='/nobackup/leopauly/logdir'
saved_path='/nobackup/leopauly/logdirk80_1_rand_frames'

print('Finished defining variables..!!',flush=True)
# Out:
# Finished defining variables..!!

# %%
## Defining placeholders in tf for images and targets
x_image = tf.placeholder(tf.float32, [None, 16,height,width,channel],name='x') 
y_true = tf.placeholder(tf.float32, [None, nb_classes],name='y_true')
y_true_cls = tf.placeholder(tf.int64, [None],name='y_true_cls')

model_keras = md.C3D_ucf101_training_model_tf(summary=False)
out=model_keras(x_image)
y_pred = tf.nn.softmax(out)
y_pred_cls = tf.argmax(out, dimension=1)
correct_prediction = tf.equal(y_pred_cls, y_true_cls)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

print('Miscellenious items finished..!!',flush=True)
# Out:
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:392: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(64, (3, 3, 3), activation="relu", name="conv1", input_shape=(16, 112, ..., padding="same")`
#   input_shape=input_shape))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:394: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2), name="pool1", padding="valid")`
#   border_mode='valid', name='pool1'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:397: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(128, (3, 3, 3), activation="relu", name="conv2", padding="same")`
#   border_mode='same', name='conv2'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:399: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), name="pool2", padding="valid")`
#   border_mode='valid', name='pool2'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:402: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(256, (3, 3, 3), activation="relu", name="conv3a", padding="same")`
#   border_mode='same', name='conv3a'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:404: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(256, (3, 3, 3), activation="relu", name="conv3b", padding="same")`
#   border_mode='same', name='conv3b'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:406: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), name="pool3", padding="valid")`
#   border_mode='valid', name='pool3'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:409: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(512, (3, 3, 3), activation="relu", name="conv4a", padding="same")`
#   border_mode='same', name='conv4a'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:411: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(512, (3, 3, 3), activation="relu", name="conv4b", padding="same")`
#   border_mode='same', name='conv4b'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:413: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), name="pool4", padding="valid")`
#   border_mode='valid', name='pool4'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:416: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(512, (3, 3, 3), activation="relu", name="conv5a", padding="same")`
#   border_mode='same', name='conv5a'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:418: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(512, (3, 3, 3), activation="relu", name="conv5b", padding="same")`
#   border_mode='same', name='conv5b'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:421: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), name="pool5", padding="valid")`
#   border_mode='valid', name='pool5'))
# Miscellenious items finished..!!

# %%
#### Training & testing
def testing(iterations,loops):
    #print(test_images.shape)
    #print(test_labels_cls)
    test_score=0
    for j in range(int(memory_batch_size_test/batch_size_test)-1):
        test_score_= sess.run([accuracy], feed_dict={x_image:test_images[(batch_size_test*j):(batch_size_test*(j+1))],y_true_cls:test_labels_cls[(batch_size_test*j):(batch_size_test*(j+1))],K.learning_phase(): 0 })
        #print('returned value',test_score_)
        print(test_score_)
        test_score=test_score+sum(test_score_)
    print('Test accuracy after iteration:',iterations,',loop:',loops,'is:',test_score/(j+1),flush=True)

# %%
## Loading Testing data
start_time = time.time()
test_images, test_labels_cls, next_batch_start, _ = ucf.read_vid_and_label_rand_frames('./UCF101_data_preparation/test.list',memory_batch_size_test,-1,16,112,normalisation=False)     
end_time = time.time()
time_dif = end_time - start_time
print("Time usage for loading training dataset: " + str(timedelta(seconds=int(round(time_dif)))),flush=True)
test_labels=keras.utils.to_categorical(test_labels_cls, num_classes=nb_classes)
print('testing data loaded',flush=True)
# Out:
# Loading /nobackup/leopauly/UCF-101_video/Diving/v_Diving_g13_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Mixing/v_Mixing_g08_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingDaf/v_PlayingDaf_g09_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/VolleyballSpiking/v_VolleyballSpiking_g23_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Hammering/v_Hammering_g05_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingSpeedBag/v_BoxingSpeedBag_g14_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Rowing/v_Rowing_g10_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WallPushups/v_WallPushups_g14_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/IceDancing/v_IceDancing_g25_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WallPushups/v_WallPushups_g17_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SkyDiving/v_SkyDiving_g19_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SumoWrestling/v_SumoWrestling_g18_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SalsaSpin/v_SalsaSpin_g12_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HandstandPushups/v_HandStandPushups_g18_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowingCandles/v_BlowingCandles_g18_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingSpeedBag/v_BoxingSpeedBag_g13_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FieldHockeyPenalty/v_FieldHockeyPenalty_g08_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TennisSwing/v_TennisSwing_g02_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Basketball/v_Basketball_g09_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Punch/v_Punch_g11_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FrisbeeCatch/v_FrisbeeCatch_g06_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Drumming/v_Drumming_g07_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PommelHorse/v_PommelHorse_g22_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/MilitaryParade/v_MilitaryParade_g09_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BodyWeightSquats/v_BodyWeightSquats_g20_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HandstandPushups/v_HandStandPushups_g09_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HighJump/v_HighJump_g12_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HorseRiding/v_HorseRiding_g11_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Rowing/v_Rowing_g11_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BasketballDunk/v_BasketballDunk_g04_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Drumming/v_Drumming_g04_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Fencing/v_Fencing_g04_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Kayaking/v_Kayaking_g02_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Biking/v_Biking_g09_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BrushingTeeth/v_BrushingTeeth_g09_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JumpingJack/v_JumpingJack_g15_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingPunchingBag/v_BoxingPunchingBag_g15_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JumpRope/v_JumpRope_g17_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RopeClimbing/v_RopeClimbing_g20_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Kayaking/v_Kayaking_g25_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RopeClimbing/v_RopeClimbing_g15_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BodyWeightSquats/v_BodyWeightSquats_g09_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingSpeedBag/v_BoxingSpeedBag_g06_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingGuitar/v_PlayingGuitar_g21_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BaseballPitch/v_BaseballPitch_g08_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingSitar/v_PlayingSitar_g19_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CuttingInKitchen/v_CuttingInKitchen_g22_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PizzaTossing/v_PizzaTossing_g04_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TaiChi/v_TaiChi_g03_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HorseRiding/v_HorseRiding_g10_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/LongJump/v_LongJump_g10_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TennisSwing/v_TennisSwing_g19_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Drumming/v_Drumming_g20_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SkateBoarding/v_SkateBoarding_g04_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/YoYo/v_YoYo_g13_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ThrowDiscus/v_ThrowDiscus_g10_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CuttingInKitchen/v_CuttingInKitchen_g08_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingPunchingBag/v_BoxingPunchingBag_g12_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HammerThrow/v_HammerThrow_g02_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Punch/v_Punch_g14_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Typing/v_Typing_g13_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PommelHorse/v_PommelHorse_g12_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RopeClimbing/v_RopeClimbing_g24_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Hammering/v_Hammering_g09_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Skijet/v_Skijet_g03_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RockClimbingIndoor/v_RockClimbingIndoor_g19_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ApplyEyeMakeup/v_ApplyEyeMakeup_g21_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Nunchucks/v_Nunchucks_g10_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingPunchingBag/v_BoxingPunchingBag_g14_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingViolin/v_PlayingViolin_g24_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Hammering/v_Hammering_g13_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TaiChi/v_TaiChi_g21_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Haircut/v_Haircut_g21_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingSitar/v_PlayingSitar_g03_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FrisbeeCatch/v_FrisbeeCatch_g19_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BrushingTeeth/v_BrushingTeeth_g01_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HeadMassage/v_HeadMassage_g16_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Kayaking/v_Kayaking_g03_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/UnevenBars/v_UnevenBars_g13_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Rafting/v_Rafting_g25_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WalkingWithDog/v_WalkingWithDog_g24_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CleanAndJerk/v_CleanAndJerk_g12_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FloorGymnastics/v_FloorGymnastics_g16_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TennisSwing/v_TennisSwing_g22_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WritingOnBoard/v_WritingOnBoard_g03_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ApplyEyeMakeup/v_ApplyEyeMakeup_g02_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BaseballPitch/v_BaseballPitch_g06_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Nunchucks/v_Nunchucks_g16_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/YoYo/v_YoYo_g08_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BasketballDunk/v_BasketballDunk_g11_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Kayaking/v_Kayaking_g07_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingCello/v_PlayingCello_g24_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingSitar/v_PlayingSitar_g01_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingDhol/v_PlayingDhol_g19_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Shotput/v_Shotput_g09_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/GolfSwing/v_GolfSwing_g25_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BrushingTeeth/v_BrushingTeeth_g20_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowDryHair/v_BlowDryHair_g09_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FrisbeeCatch/v_FrisbeeCatch_g14_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TaiChi/v_TaiChi_g04_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Knitting/v_Knitting_g20_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SkyDiving/v_SkyDiving_g10_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Drumming/v_Drumming_g01_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BenchPress/v_BenchPress_g24_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/UnevenBars/v_UnevenBars_g20_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HandstandWalking/v_HandstandWalking_g08_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SoccerJuggling/v_SoccerJuggling_g07_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Punch/v_Punch_g04_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WallPushups/v_WallPushups_g04_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Hammering/v_Hammering_g01_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Swing/v_Swing_g16_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowDryHair/v_BlowDryHair_g20_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Shotput/v_Shotput_g04_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Billiards/v_Billiards_g11_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingGuitar/v_PlayingGuitar_g05_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PizzaTossing/v_PizzaTossing_g15_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HulaHoop/v_HulaHoop_g18_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingSitar/v_PlayingSitar_g09_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CricketShot/v_CricketShot_g23_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ShavingBeard/v_ShavingBeard_g14_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingSitar/v_PlayingSitar_g16_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingTabla/v_PlayingTabla_g06_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Haircut/v_Haircut_g06_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TennisSwing/v_TennisSwing_g21_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HammerThrow/v_HammerThrow_g22_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingFlute/v_PlayingFlute_g12_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SoccerJuggling/v_SoccerJuggling_g05_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BalanceBeam/v_BalanceBeam_g08_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WritingOnBoard/v_WritingOnBoard_g16_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TaiChi/v_TaiChi_g22_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowDryHair/v_BlowDryHair_g15_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Haircut/v_Haircut_g16_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BalanceBeam/v_BalanceBeam_g14_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/MoppingFloor/v_MoppingFloor_g06_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HandstandPushups/v_HandStandPushups_g12_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BasketballDunk/v_BasketballDunk_g23_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Rafting/v_Rafting_g11_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Skijet/v_Skijet_g10_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Nunchucks/v_Nunchucks_g19_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PoleVault/v_PoleVault_g05_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Skiing/v_Skiing_g25_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Rafting/v_Rafting_g12_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BabyCrawling/v_BabyCrawling_g12_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Drumming/v_Drumming_g24_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JavelinThrow/v_JavelinThrow_g13_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/GolfSwing/v_GolfSwing_g03_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Punch/v_Punch_g07_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SoccerJuggling/v_SoccerJuggling_g23_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Biking/v_Biking_g11_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FloorGymnastics/v_FloorGymnastics_g23_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FrisbeeCatch/v_FrisbeeCatch_g21_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Knitting/v_Knitting_g05_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BasketballDunk/v_BasketballDunk_g23_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PizzaTossing/v_PizzaTossing_g04_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingDaf/v_PlayingDaf_g09_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CliffDiving/v_CliffDiving_g23_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ShavingBeard/v_ShavingBeard_g17_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PizzaTossing/v_PizzaTossing_g12_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FloorGymnastics/v_FloorGymnastics_g04_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RockClimbingIndoor/v_RockClimbingIndoor_g14_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ParallelBars/v_ParallelBars_g07_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Shotput/v_Shotput_g11_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CliffDiving/v_CliffDiving_g13_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RockClimbingIndoor/v_RockClimbingIndoor_g10_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingGuitar/v_PlayingGuitar_g10_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JumpRope/v_JumpRope_g11_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowDryHair/v_BlowDryHair_g19_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TaiChi/v_TaiChi_g24_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BasketballDunk/v_BasketballDunk_g12_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BaseballPitch/v_BaseballPitch_g18_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Kayaking/v_Kayaking_g20_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SkateBoarding/v_SkateBoarding_g13_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Rafting/v_Rafting_g13_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/MilitaryParade/v_MilitaryParade_g18_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingViolin/v_PlayingViolin_g17_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ApplyLipstick/v_ApplyLipstick_g16_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/IceDancing/v_IceDancing_g20_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PullUps/v_PullUps_g22_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CliffDiving/v_CliffDiving_g10_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Drumming/v_Drumming_g06_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/LongJump/v_LongJump_g12_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Hammering/v_Hammering_g15_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WritingOnBoard/v_WritingOnBoard_g07_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SkateBoarding/v_SkateBoarding_g24_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Shotput/v_Shotput_g11_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Rafting/v_Rafting_g20_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JumpRope/v_JumpRope_g25_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Rafting/v_Rafting_g23_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BasketballDunk/v_BasketballDunk_g24_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PommelHorse/v_PommelHorse_g19_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Archery/v_Archery_g25_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingFlute/v_PlayingFlute_g25_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BabyCrawling/v_BabyCrawling_g20_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RockClimbingIndoor/v_RockClimbingIndoor_g03_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Basketball/v_Basketball_g02_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CricketShot/v_CricketShot_g08_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Punch/v_Punch_g13_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/MoppingFloor/v_MoppingFloor_g08_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Drumming/v_Drumming_g25_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FloorGymnastics/v_FloorGymnastics_g17_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Nunchucks/v_Nunchucks_g01_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/LongJump/v_LongJump_g22_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Skiing/v_Skiing_g11_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingGuitar/v_PlayingGuitar_g11_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/MoppingFloor/v_MoppingFloor_g25_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JumpingJack/v_JumpingJack_g18_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BasketballDunk/v_BasketballDunk_g22_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WallPushups/v_WallPushups_g06_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Haircut/v_Haircut_g10_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Fencing/v_Fencing_g05_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/UnevenBars/v_UnevenBars_g12_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JugglingBalls/v_JugglingBalls_g17_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/GolfSwing/v_GolfSwing_g25_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RopeClimbing/v_RopeClimbing_g13_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/GolfSwing/v_GolfSwing_g14_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Biking/v_Biking_g15_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WalkingWithDog/v_WalkingWithDog_g13_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PullUps/v_PullUps_g21_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingViolin/v_PlayingViolin_g05_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Typing/v_Typing_g11_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Punch/v_Punch_g18_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Surfing/v_Surfing_g07_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HeadMassage/v_HeadMassage_g23_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Shotput/v_Shotput_g08_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TaiChi/v_TaiChi_g19_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingSitar/v_PlayingSitar_g20_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FieldHockeyPenalty/v_FieldHockeyPenalty_g06_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Kayaking/v_Kayaking_g21_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Knitting/v_Knitting_g11_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FrontCrawl/v_FrontCrawl_g08_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ApplyLipstick/v_ApplyLipstick_g13_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Kayaking/v_Kayaking_g18_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TableTennisShot/v_TableTennisShot_g24_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HammerThrow/v_HammerThrow_g03_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Haircut/v_Haircut_g01_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Mixing/v_Mixing_g13_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Lunges/v_Lunges_g17_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SalsaSpin/v_SalsaSpin_g08_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingPunchingBag/v_BoxingPunchingBag_g10_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FloorGymnastics/v_FloorGymnastics_g12_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingCello/v_PlayingCello_g02_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BaseballPitch/v_BaseballPitch_g19_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PushUps/v_PushUps_g10_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PommelHorse/v_PommelHorse_g07_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Haircut/v_Haircut_g19_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Rowing/v_Rowing_g04_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FieldHockeyPenalty/v_FieldHockeyPenalty_g21_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Rafting/v_Rafting_g16_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingSitar/v_PlayingSitar_g22_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/YoYo/v_YoYo_g22_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FieldHockeyPenalty/v_FieldHockeyPenalty_g05_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CricketBowling/v_CricketBowling_g03_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SkateBoarding/v_SkateBoarding_g14_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HandstandPushups/v_HandStandPushups_g14_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingPunchingBag/v_BoxingPunchingBag_g07_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Lunges/v_Lunges_g20_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingPunchingBag/v_BoxingPunchingBag_g09_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingPiano/v_PlayingPiano_g13_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingViolin/v_PlayingViolin_g02_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/YoYo/v_YoYo_g04_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Mixing/v_Mixing_g04_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SoccerJuggling/v_SoccerJuggling_g12_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CliffDiving/v_CliffDiving_g14_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HammerThrow/v_HammerThrow_g19_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CliffDiving/v_CliffDiving_g06_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingCello/v_PlayingCello_g08_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PizzaTossing/v_PizzaTossing_g20_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TennisSwing/v_TennisSwing_g08_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TennisSwing/v_TennisSwing_g07_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingPiano/v_PlayingPiano_g06_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingGuitar/v_PlayingGuitar_g20_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SoccerPenalty/v_SoccerPenalty_g07_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SumoWrestling/v_SumoWrestling_g15_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Swing/v_Swing_g18_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PizzaTossing/v_PizzaTossing_g18_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Mixing/v_Mixing_g24_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PommelHorse/v_PommelHorse_g16_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FrontCrawl/v_FrontCrawl_g03_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JavelinThrow/v_JavelinThrow_g12_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PizzaTossing/v_PizzaTossing_g06_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Haircut/v_Haircut_g14_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Knitting/v_Knitting_g03_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Rowing/v_Rowing_g17_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/GolfSwing/v_GolfSwing_g23_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/MilitaryParade/v_MilitaryParade_g25_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SoccerJuggling/v_SoccerJuggling_g18_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ShavingBeard/v_ShavingBeard_g13_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/MilitaryParade/v_MilitaryParade_g15_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PizzaTossing/v_PizzaTossing_g24_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/GolfSwing/v_GolfSwing_g06_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Drumming/v_Drumming_g01_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Typing/v_Typing_g12_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/MoppingFloor/v_MoppingFloor_g19_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TableTennisShot/v_TableTennisShot_g23_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HighJump/v_HighJump_g16_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BreastStroke/v_BreastStroke_g22_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/YoYo/v_YoYo_g08_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Knitting/v_Knitting_g17_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingDhol/v_PlayingDhol_g15_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HammerThrow/v_HammerThrow_g23_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Bowling/v_Bowling_g19_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Kayaking/v_Kayaking_g13_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingFlute/v_PlayingFlute_g07_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Punch/v_Punch_g22_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PushUps/v_PushUps_g15_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/IceDancing/v_IceDancing_g11_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TennisSwing/v_TennisSwing_g04_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BalanceBeam/v_BalanceBeam_g17_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FrontCrawl/v_FrontCrawl_g17_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WritingOnBoard/v_WritingOnBoard_g12_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingTabla/v_PlayingTabla_g22_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Diving/v_Diving_g11_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ApplyEyeMakeup/v_ApplyEyeMakeup_g13_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HandstandWalking/v_HandstandWalking_g09_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BalanceBeam/v_BalanceBeam_g10_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowingCandles/v_BlowingCandles_g17_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowDryHair/v_BlowDryHair_g08_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CliffDiving/v_CliffDiving_g07_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HandstandPushups/v_HandStandPushups_g20_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SkyDiving/v_SkyDiving_g06_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ShavingBeard/v_ShavingBeard_g01_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BabyCrawling/v_BabyCrawling_g03_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BalanceBeam/v_BalanceBeam_g11_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HorseRiding/v_HorseRiding_g04_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SumoWrestling/v_SumoWrestling_g02_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Knitting/v_Knitting_g13_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Lunges/v_Lunges_g19_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FrontCrawl/v_FrontCrawl_g22_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BenchPress/v_BenchPress_g16_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BandMarching/v_BandMarching_g24_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Hammering/v_Hammering_g22_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HandstandWalking/v_HandstandWalking_g05_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/GolfSwing/v_GolfSwing_g10_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HammerThrow/v_HammerThrow_g12_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SoccerPenalty/v_SoccerPenalty_g23_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CuttingInKitchen/v_CuttingInKitchen_g18_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BandMarching/v_BandMarching_g25_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingFlute/v_PlayingFlute_g20_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingPunchingBag/v_BoxingPunchingBag_g01_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Skiing/v_Skiing_g06_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingViolin/v_PlayingViolin_g19_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RopeClimbing/v_RopeClimbing_g25_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ParallelBars/v_ParallelBars_g15_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PullUps/v_PullUps_g15_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Archery/v_Archery_g21_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HorseRiding/v_HorseRiding_g18_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingPunchingBag/v_BoxingPunchingBag_g13_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowDryHair/v_BlowDryHair_g10_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Shotput/v_Shotput_g17_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RockClimbingIndoor/v_RockClimbingIndoor_g12_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PoleVault/v_PoleVault_g04_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/GolfSwing/v_GolfSwing_g08_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/GolfSwing/v_GolfSwing_g16_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TaiChi/v_TaiChi_g13_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JavelinThrow/v_JavelinThrow_g05_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ApplyLipstick/v_ApplyLipstick_g25_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BabyCrawling/v_BabyCrawling_g04_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BaseballPitch/v_BaseballPitch_g16_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BabyCrawling/v_BabyCrawling_g18_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Knitting/v_Knitting_g18_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HammerThrow/v_HammerThrow_g04_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RopeClimbing/v_RopeClimbing_g13_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BabyCrawling/v_BabyCrawling_g11_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SoccerJuggling/v_SoccerJuggling_g21_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WalkingWithDog/v_WalkingWithDog_g14_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RockClimbingIndoor/v_RockClimbingIndoor_g22_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingGuitar/v_PlayingGuitar_g18_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ThrowDiscus/v_ThrowDiscus_g04_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BaseballPitch/v_BaseballPitch_g13_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Haircut/v_Haircut_g24_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/StillRings/v_StillRings_g21_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PizzaTossing/v_PizzaTossing_g09_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingDaf/v_PlayingDaf_g11_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Drumming/v_Drumming_g02_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JugglingBalls/v_JugglingBalls_g23_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ApplyEyeMakeup/v_ApplyEyeMakeup_g17_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingSpeedBag/v_BoxingSpeedBag_g12_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Drumming/v_Drumming_g03_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/UnevenBars/v_UnevenBars_g19_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingPiano/v_PlayingPiano_g21_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Knitting/v_Knitting_g14_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/YoYo/v_YoYo_g22_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ApplyLipstick/v_ApplyLipstick_g17_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowingCandles/v_BlowingCandles_g09_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/MilitaryParade/v_MilitaryParade_g07_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingTabla/v_PlayingTabla_g08_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FloorGymnastics/v_FloorGymnastics_g09_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BandMarching/v_BandMarching_g21_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BrushingTeeth/v_BrushingTeeth_g24_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Nunchucks/v_Nunchucks_g17_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FrontCrawl/v_FrontCrawl_g15_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BaseballPitch/v_BaseballPitch_g08_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PoleVault/v_PoleVault_g11_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SalsaSpin/v_SalsaSpin_g22_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Archery/v_Archery_g01_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowDryHair/v_BlowDryHair_g17_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WritingOnBoard/v_WritingOnBoard_g18_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BaseballPitch/v_BaseballPitch_g17_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Skijet/v_Skijet_g23_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FloorGymnastics/v_FloorGymnastics_g10_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Bowling/v_Bowling_g23_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingDhol/v_PlayingDhol_g04_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FrisbeeCatch/v_FrisbeeCatch_g20_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RockClimbingIndoor/v_RockClimbingIndoor_g17_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FrontCrawl/v_FrontCrawl_g11_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RopeClimbing/v_RopeClimbing_g17_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BabyCrawling/v_BabyCrawling_g25_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HandstandPushups/v_HandStandPushups_g21_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Skiing/v_Skiing_g16_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HorseRiding/v_HorseRiding_g01_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Surfing/v_Surfing_g15_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TableTennisShot/v_TableTennisShot_g11_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ParallelBars/v_ParallelBars_g20_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JumpRope/v_JumpRope_g24_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Basketball/v_Basketball_g20_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Basketball/v_Basketball_g14_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Basketball/v_Basketball_g14_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingDaf/v_PlayingDaf_g22_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ParallelBars/v_ParallelBars_g22_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HeadMassage/v_HeadMassage_g03_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SkyDiving/v_SkyDiving_g05_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HeadMassage/v_HeadMassage_g10_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BaseballPitch/v_BaseballPitch_g01_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingSitar/v_PlayingSitar_g08_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ApplyEyeMakeup/v_ApplyEyeMakeup_g10_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingGuitar/v_PlayingGuitar_g17_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HammerThrow/v_HammerThrow_g12_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CleanAndJerk/v_CleanAndJerk_g05_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Bowling/v_Bowling_g20_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JugglingBalls/v_JugglingBalls_g15_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HeadMassage/v_HeadMassage_g08_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Mixing/v_Mixing_g25_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CricketShot/v_CricketShot_g13_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Hammering/v_Hammering_g03_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Lunges/v_Lunges_g21_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingDaf/v_PlayingDaf_g03_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TableTennisShot/v_TableTennisShot_g24_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WalkingWithDog/v_WalkingWithDog_g03_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Drumming/v_Drumming_g12_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CliffDiving/v_CliffDiving_g22_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Shotput/v_Shotput_g03_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TableTennisShot/v_TableTennisShot_g25_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/MoppingFloor/v_MoppingFloor_g04_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HulaHoop/v_HulaHoop_g04_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Typing/v_Typing_g20_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TableTennisShot/v_TableTennisShot_g05_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SkyDiving/v_SkyDiving_g20_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Diving/v_Diving_g01_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HeadMassage/v_HeadMassage_g06_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CricketShot/v_CricketShot_g03_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HandstandPushups/v_HandStandPushups_g06_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PommelHorse/v_PommelHorse_g17_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FloorGymnastics/v_FloorGymnastics_g12_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FieldHockeyPenalty/v_FieldHockeyPenalty_g10_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HandstandPushups/v_HandStandPushups_g13_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PoleVault/v_PoleVault_g08_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TennisSwing/v_TennisSwing_g01_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/MilitaryParade/v_MilitaryParade_g21_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JumpRope/v_JumpRope_g06_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Typing/v_Typing_g04_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PommelHorse/v_PommelHorse_g21_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Biking/v_Biking_g17_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingSpeedBag/v_BoxingSpeedBag_g03_c05...
# ret_arr (16, 240, 320, 3)
# ...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Rafting/v_Rafting_g22_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SoccerJuggling/v_SoccerJuggling_g14_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingDhol/v_PlayingDhol_g16_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingFlute/v_PlayingFlute_g11_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JumpRope/v_JumpRope_g11_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PushUps/v_PushUps_g16_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CliffDiving/v_CliffDiving_g08_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/StillRings/v_StillRings_g03_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Lunges/v_Lunges_g14_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingSitar/v_PlayingSitar_g04_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BaseballPitch/v_BaseballPitch_g01_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowDryHair/v_BlowDryHair_g06_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HorseRiding/v_HorseRiding_g14_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PushUps/v_PushUps_g04_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Rowing/v_Rowing_g25_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HighJump/v_HighJump_g01_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HammerThrow/v_HammerThrow_g09_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/UnevenBars/v_UnevenBars_g09_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HorseRiding/v_HorseRiding_g03_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/GolfSwing/v_GolfSwing_g01_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BasketballDunk/v_BasketballDunk_g21_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/YoYo/v_YoYo_g12_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SumoWrestling/v_SumoWrestling_g07_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/LongJump/v_LongJump_g14_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ParallelBars/v_ParallelBars_g06_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingDhol/v_PlayingDhol_g22_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BasketballDunk/v_BasketballDunk_g16_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/UnevenBars/v_UnevenBars_g24_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RopeClimbing/v_RopeClimbing_g16_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HammerThrow/v_HammerThrow_g25_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Bowling/v_Bowling_g06_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Lunges/v_Lunges_g22_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SumoWrestling/v_SumoWrestling_g12_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/YoYo/v_YoYo_g03_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Skijet/v_Skijet_g19_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/IceDancing/v_IceDancing_g17_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PushUps/v_PushUps_g12_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Drumming/v_Drumming_g17_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Archery/v_Archery_g17_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingGuitar/v_PlayingGuitar_g14_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HammerThrow/v_HammerThrow_g03_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Surfing/v_Surfing_g02_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowDryHair/v_BlowDryHair_g06_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Basketball/v_Basketball_g20_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/GolfSwing/v_GolfSwing_g22_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Archery/v_Archery_g24_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingPiano/v_PlayingPiano_g20_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JumpRope/v_JumpRope_g13_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingPunchingBag/v_BoxingPunchingBag_g17_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Biking/v_Biking_g10_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HeadMassage/v_HeadMassage_g19_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HorseRace/v_HorseRace_g19_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WritingOnBoard/v_WritingOnBoard_g10_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JumpRope/v_JumpRope_g24_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JumpRope/v_JumpRope_g14_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Swing/v_Swing_g13_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RopeClimbing/v_RopeClimbing_g02_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JavelinThrow/v_JavelinThrow_g24_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SoccerJuggling/v_SoccerJuggling_g20_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/VolleyballSpiking/v_VolleyballSpiking_g09_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/UnevenBars/v_UnevenBars_g11_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Typing/v_Typing_g08_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SkateBoarding/v_SkateBoarding_g12_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JugglingBalls/v_JugglingBalls_g03_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingSpeedBag/v_BoxingSpeedBag_g10_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CliffDiving/v_CliffDiving_g17_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Basketball/v_Basketball_g19_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BrushingTeeth/v_BrushingTeeth_g24_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BrushingTeeth/v_BrushingTeeth_g18_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowDryHair/v_BlowDryHair_g16_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CleanAndJerk/v_CleanAndJerk_g20_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JavelinThrow/v_JavelinThrow_g19_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Knitting/v_Knitting_g25_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BodyWeightSquats/v_BodyWeightSquats_g15_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingFlute/v_PlayingFlute_g09_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TaiChi/v_TaiChi_g11_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingDhol/v_PlayingDhol_g10_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HeadMassage/v_HeadMassage_g07_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TennisSwing/v_TennisSwing_g13_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HulaHoop/v_HulaHoop_g10_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Skijet/v_Skijet_g16_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WritingOnBoard/v_WritingOnBoard_g04_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BodyWeightSquats/v_BodyWeightSquats_g16_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingPiano/v_PlayingPiano_g14_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BrushingTeeth/v_BrushingTeeth_g02_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Skiing/v_Skiing_g24_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CricketShot/v_CricketShot_g01_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Rafting/v_Rafting_g02_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BrushingTeeth/v_BrushingTeeth_g21_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Skijet/v_Skijet_g18_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RopeClimbing/v_RopeClimbing_g09_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ThrowDiscus/v_ThrowDiscus_g17_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Diving/v_Diving_g05_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Punch/v_Punch_g04_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Punch/v_Punch_g13_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowingCandles/v_BlowingCandles_g02_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BabyCrawling/v_BabyCrawling_g09_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WritingOnBoard/v_WritingOnBoard_g21_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Mixing/v_Mixing_g05_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Haircut/v_Haircut_g19_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingCello/v_PlayingCello_g17_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JugglingBalls/v_JugglingBalls_g25_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BasketballDunk/v_BasketballDunk_g13_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/VolleyballSpiking/v_VolleyballSpiking_g04_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RopeClimbing/v_RopeClimbing_g10_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowDryHair/v_BlowDryHair_g13_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Bowling/v_Bowling_g20_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SalsaSpin/v_SalsaSpin_g06_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HulaHoop/v_HulaHoop_g13_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/VolleyballSpiking/v_VolleyballSpiking_g01_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/MoppingFloor/v_MoppingFloor_g20_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Punch/v_Punch_g16_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Typing/v_Typing_g23_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Billiards/v_Billiards_g18_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/RopeClimbing/v_RopeClimbing_g11_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SkateBoarding/v_SkateBoarding_g03_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BenchPress/v_BenchPress_g05_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingGuitar/v_PlayingGuitar_g03_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SoccerPenalty/v_SoccerPenalty_g12_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SoccerJuggling/v_SoccerJuggling_g13_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SumoWrestling/v_SumoWrestling_g14_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Punch/v_Punch_g03_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HandstandPushups/v_HandStandPushups_g16_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingSitar/v_PlayingSitar_g07_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/StillRings/v_StillRings_g11_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/JumpRope/v_JumpRope_g07_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BaseballPitch/v_BaseballPitch_g25_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Billiards/v_Billiards_g22_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BoxingSpeedBag/v_BoxingSpeedBag_g05_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PushUps/v_PushUps_g02_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BodyWeightSquats/v_BodyWeightSquats_g20_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/ShavingBeard/v_ShavingBeard_g10_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Punch/v_Punch_g01_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CricketShot/v_CricketShot_g22_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Skiing/v_Skiing_g08_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Hammering/v_Hammering_g12_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BabyCrawling/v_BabyCrawling_g13_c01...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/HorseRiding/v_HorseRiding_g16_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/FrisbeeCatch/v_FrisbeeCatch_g10_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Biking/v_Biking_g23_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BrushingTeeth/v_BrushingTeeth_g15_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/BlowDryHair/v_BlowDryHair_g24_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/WallPushups/v_WallPushups_g25_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/VolleyballSpiking/v_VolleyballSpiking_g08_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingSitar/v_PlayingSitar_g18_c05...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/SkyDiving/v_SkyDiving_g15_c04...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingCello/v_PlayingCello_g24_c07...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PlayingDaf/v_PlayingDaf_g14_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/MoppingFloor/v_MoppingFloor_g02_c06...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/TrampolineJumping/v_TrampolineJumping_g10_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/IceDancing/v_IceDancing_g22_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/Lunges/v_Lunges_g03_c03...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/PizzaTossing/v_PizzaTossing_g01_c02...
# ret_arr (16, 240, 320, 3)
# Loading /nobackup/leopauly/UCF-101_video/CuttingInKitchen/v_CuttingInKitchen_g01_c03...
# ret_arr (16, 240, 320, 3)
# (3329, 16, 112, 112, 3)
# Time usage for loading training dataset: 0:33:57
# testing data loaded

# %%
#### Start the session with logging placement.
init_op = tf.global_variables_initializer()
sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True, log_device_placement=False))
sess.run(init_op)

# Restore model weights from previously saved model

#saver = tf.train.import_meta_graph(os.path.join(saved_path,'activity_model_1.ckpt-43.meta'))
saver = tf.train.Saver()
saver.restore(sess, os.path.join(saved_path,'activity_model.ckpt-104'))
print("Model restored from file: %s" % saved_path,flush=True)
# Out:
# INFO:tensorflow:Restoring parameters from /nobackup/leopauly/logdirk80_1_rand_frames/activity_model.ckpt-104
# Model restored from file: /nobackup/leopauly/logdirk80_1_rand_frames

# %%
start_time = time.time()
testing(0,0)
end_time = time.time()
time_dif = end_time - start_time
print("Time taken for testing: " + str(timedelta(seconds=int(round(time_dif)))),flush=True)
# Out:
# [0.5]
# [0.4375]
# [0.5625]
# [0.6875]
# [0.3125]
# [0.625]
# [0.4375]
# [0.375]
# [0.5625]
# [0.5]
# [0.6875]
# [0.625]
# [0.375]
# [0.625]
# [0.5]
# [0.5625]
# [0.4375]
# [0.5625]
# [0.5625]
# [0.4375]
# [0.5625]
# [0.3125]
# [0.5625]
# [0.625]
# [0.4375]
# [0.625]
# [0.4375]
# [0.625]
# [0.5]
# [0.5625]
# [0.75]
# [0.5625]
# [0.625]
# [0.5625]
# [0.4375]
# [0.5625]
# [0.5625]
# [0.5]
# [0.375]
# [0.6875]
# [0.625]
# [0.375]
# [0.4375]
# [0.5]
# [0.75]
# [0.75]
# [0.5625]
# [0.75]
# [0.5]
# [0.6875]
# [0.6875]
# [0.3125]
# [0.625]
# [0.4375]
# [0.6875]
# [0.5625]
# [0.625]
# [0.5625]
# [0.4375]
# [0.75]
# [0.625]
# [0.3125]
# [0.4375]
# [0.4375]
# [0.5625]
# [0.5625]
# [0.5625]
# [0.5625]
# [0.6875]
# [0.5]
# [0.4375]
# [0.5625]
# [0.5]
# [0.625]
# [0.625]
# [0.5625]
# [0.5]
# [0.4375]
# [0.5625]
# [0.5]
# [0.6875]
# [0.5]
# [0.5]
# [0.6875]
# [0.5]
# [0.5]
# [0.4375]
# [0.6875]
# [0.625]
# [0.375]
# [0.5625]
# [0.5625]
# [0.375]
# [0.5]
# [0.625]
# [0.6875]
# [0.625]
# [0.625]
# [0.75]
# [0.4375]
# [0.4375]
# [0.5625]
# [0.4375]
# [0.5]
# [0.6875]
# [0.625]
# [0.5]
# [0.5625]
# [0.5]
# [0.75]
# [0.5625]
# [0.625]
# [0.4375]
# [0.625]
# [0.5625]
# [0.5]
# [0.625]
# [0.625]
# [0.6875]
# [0.5]
# [0.625]
# [0.4375]
# [0.4375]
# [0.6875]
# [0.5]
# [0.4375]
# [0.5]
# [0.625]
# [0.5]
# [0.3125]
# [0.8125]
# [0.625]
# [0.4375]
# [0.5625]
# [0.5]
# [0.5]
# [0.625]
# [0.6875]
# [0.625]
# [0.5]
# [0.4375]
# [0.5625]
# [0.6875]
# [0.5625]
# [0.625]
# [0.4375]
# [0.4375]
# [0.375]
# [0.625]
# [0.625]
# [0.625]
# [0.5625]
# [0.5]
# [0.375]
# [0.5625]
# [0.625]
# [0.4375]
# [0.5625]
# [0.5625]
# [0.625]
# [0.8125]
# [0.5]
# [0.5]
# [0.5625]
# [0.875]
# [0.75]
# [0.4375]
# [0.5]
# [0.625]
# [0.5]
# [0.5625]
# [0.5625]
# [0.625]
# [0.625]
# [0.5625]
# [0.5625]
# [0.4375]
# [0.5]
# [0.75]
# [0.625]
# [0.25]
# [0.5]
# [0.6875]
# [0.625]
# [0.5625]
# [0.75]
# [0.5]
# [0.5]
# [0.375]
# [0.5625]
# [0.4375]
# [0.375]
# [0.6875]
# [0.4375]
# [0.75]
# [0.625]
# [0.625]
# [0.5]
# [0.625]
# [0.3125]
# [0.625]
# [0.5]
# [0.375]
# [0.5625]
# [0.625]
# [0.625]
# [0.4375]
# Test accuracy after iteration: 0 ,loop: 0 is: 0.551026570048
# Time taken for testing: 0:01:38

# %%
#sess.close()

# %%
print([n.name for n in tf.get_default_graph().as_graph_def().node])
# Out:
# ['x', 'y_true', 'y_true_cls', 'conv1_input', 'conv1/random_uniform/shape', 'conv1/random_uniform/min', 'conv1/random_uniform/max', 'conv1/random_uniform/RandomUniform', 'conv1/random_uniform/sub', 'conv1/random_uniform/mul', 'conv1/random_uniform', 'conv1/kernel', 'conv1/kernel/Assign', 'conv1/kernel/read', 'conv1/Const', 'conv1/bias', 'conv1/bias/Assign', 'conv1/bias/read', 'conv1/convolution/Shape', 'conv1/convolution/dilation_rate', 'conv1/convolution', 'conv1/Reshape/shape', 'conv1/Reshape', 'conv1/add', 'conv1/Relu', 'pool1/MaxPool3D', 'conv2/random_uniform/shape', 'conv2/random_uniform/min', 'conv2/random_uniform/max', 'conv2/random_uniform/RandomUniform', 'conv2/random_uniform/sub', 'conv2/random_uniform/mul', 'conv2/random_uniform', 'conv2/kernel', 'conv2/kernel/Assign', 'conv2/kernel/read', 'conv2/Const', 'conv2/bias', 'conv2/bias/Assign', 'conv2/bias/read', 'conv2/convolution/Shape', 'conv2/convolution/dilation_rate', 'conv2/convolution', 'conv2/Reshape/shape', 'conv2/Reshape', 'conv2/add', 'conv2/Relu', 'pool2/MaxPool3D', 'conv3a/random_uniform/shape', 'conv3a/random_uniform/min', 'conv3a/random_uniform/max', 'conv3a/random_uniform/RandomUniform', 'conv3a/random_uniform/sub', 'conv3a/random_uniform/mul', 'conv3a/random_uniform', 'conv3a/kernel', 'conv3a/kernel/Assign', 'conv3a/kernel/read', 'conv3a/Const', 'conv3a/bias', 'conv3a/bias/Assign', 'conv3a/bias/read', 'conv3a/convolution/Shape', 'conv3a/convolution/dilation_rate', 'conv3a/convolution', 'conv3a/Reshape/shape', 'conv3a/Reshape', 'conv3a/add', 'conv3a/Relu', 'conv3b/random_uniform/shape', 'conv3b/random_uniform/min', 'conv3b/random_uniform/max', 'conv3b/random_uniform/RandomUniform', 'conv3b/random_uniform/sub', 'conv3b/random_uniform/mul', 'conv3b/random_uniform', 'conv3b/kernel', 'conv3b/kernel/Assign', 'conv3b/kernel/read', 'conv3b/Const', 'conv3b/bias', 'conv3b/bias/Assign', 'conv3b/bias/read', 'conv3b/convolution/Shape', 'conv3b/convolution/dilation_rate', 'conv3b/convolution', 'conv3b/Reshape/shape', 'conv3b/Reshape', 'conv3b/add', 'conv3b/Relu', 'pool3/MaxPool3D', 'conv4a/random_uniform/shape', 'conv4a/random_uniform/min', 'conv4a/random_uniform/max', 'conv4a/random_uniform/RandomUniform', 'conv4a/random_uniform/sub', 'conv4a/random_uniform/mul', 'conv4a/random_uniform', 'conv4a/kernel', 'conv4a/kernel/Assign', 'conv4a/kernel/read', 'conv4a/Const', 'conv4a/bias', 'conv4a/bias/Assign', 'conv4a/bias/read', 'conv4a/convolution/Shape', 'conv4a/convolution/dilation_rate', 'conv4a/convolution', 'conv4a/Reshape/shape', 'conv4a/Reshape', 'conv4a/add', 'conv4a/Relu', 'conv4b/random_uniform/shape', 'conv4b/random_uniform/min', 'conv4b/random_uniform/max', 'conv4b/random_uniform/RandomUniform', 'conv4b/random_uniform/sub', 'conv4b/random_uniform/mul', 'conv4b/random_uniform', 'conv4b/kernel', 'conv4b/kernel/Assign', 'conv4b/kernel/read', 'conv4b/Const', 'conv4b/bias', 'conv4b/bias/Assign', 'conv4b/bias/read', 'conv4b/convolution/Shape', 'conv4b/convolution/dilation_rate', 'conv4b/convolution', 'conv4b/Reshape/shape', 'conv4b/Reshape', 'conv4b/add', 'conv4b/Relu', 'pool4/MaxPool3D', 'conv5a/random_uniform/shape', 'conv5a/random_uniform/min', 'conv5a/random_uniform/max', 'conv5a/random_uniform/RandomUniform', 'conv5a/random_uniform/sub', 'conv5a/random_uniform/mul', 'conv5a/random_uniform', 'conv5a/kernel', 'conv5a/kernel/Assign', 'conv5a/kernel/read', 'conv5a/Const', 'conv5a/bias', 'conv5a/bias/Assign', 'conv5a/bias/read', 'conv5a/convolution/Shape', 'conv5a/convolution/dilation_rate', 'conv5a/convolution', 'conv5a/Reshape/shape', 'conv5a/Reshape', 'conv5a/add', 'conv5a/Relu', 'conv5b/random_uniform/shape', 'conv5b/random_uniform/min', 'conv5b/random_uniform/max', 'conv5b/random_uniform/RandomUniform', 'conv5b/random_uniform/sub', 'conv5b/random_uniform/mul', 'conv5b/random_uniform', 'conv5b/kernel', 'conv5b/kernel/Assign', 'conv5b/kernel/read', 'conv5b/Const', 'conv5b/bias', 'conv5b/bias/Assign', 'conv5b/bias/read', 'conv5b/convolution/Shape', 'conv5b/convolutio ...

# %%
for op in tf.get_default_graph().get_operations():
    print(op.name)
# Out:
# x
# y_true
# y_true_cls
# conv1_input
# conv1/random_uniform/shape
# conv1/random_uniform/min
# conv1/random_uniform/max
# conv1/random_uniform/RandomUniform
# conv1/random_uniform/sub
# conv1/random_uniform/mul
# conv1/random_uniform
# conv1/kernel
# conv1/kernel/Assign
# conv1/kernel/read
# conv1/Const
# conv1/bias
# conv1/bias/Assign
# conv1/bias/read
# conv1/convolution/Shape
# conv1/convolution/dilation_rate
# conv1/convolution
# conv1/Reshape/shape
# conv1/Reshape
# conv1/add
# conv1/Relu
# pool1/MaxPool3D
# conv2/random_uniform/shape
# conv2/random_uniform/min
# conv2/random_uniform/max
# conv2/random_uniform/RandomUniform
# conv2/random_uniform/sub
# conv2/random_uniform/mul
# conv2/random_uniform
# conv2/kernel
# conv2/kernel/Assign
# conv2/kernel/read
# conv2/Const
# conv2/bias
# conv2/bias/Assign
# conv2/bias/read
# conv2/convolution/Shape
# conv2/convolution/dilation_rate
# conv2/convolution
# conv2/Reshape/shape
# conv2/Reshape
# conv2/add
# conv2/Relu
# pool2/MaxPool3D
# conv3a/random_uniform/shape
# conv3a/random_uniform/min
# conv3a/random_uniform/max
# conv3a/random_uniform/RandomUniform
# conv3a/random_uniform/sub
# conv3a/random_uniform/mul
# conv3a/random_uniform
# conv3a/kernel
# conv3a/kernel/Assign
# conv3a/kernel/read
# conv3a/Const
# conv3a/bias
# conv3a/bias/Assign
# conv3a/bias/read
# conv3a/convolution/Shape
# conv3a/convolution/dilation_rate
# conv3a/convolution
# conv3a/Reshape/shape
# conv3a/Reshape
# conv3a/add
# conv3a/Relu
# conv3b/random_uniform/shape
# conv3b/random_uniform/min
# conv3b/random_uniform/max
# conv3b/random_uniform/RandomUniform
# conv3b/random_uniform/sub
# conv3b/random_uniform/mul
# conv3b/random_uniform
# conv3b/kernel
# conv3b/kernel/Assign
# conv3b/kernel/read
# conv3b/Const
# conv3b/bias
# conv3b/bias/Assign
# conv3b/bias/read
# conv3b/convolution/Shape
# conv3b/convolution/dilation_rate
# conv3b/convolution
# conv3b/Reshape/shape
# conv3b/Reshape
# conv3b/add
# conv3b/Relu
# pool3/MaxPool3D
# conv4a/random_uniform/shape
# conv4a/random_uniform/min
# conv4a/random_uniform/max
# conv4a/random_uniform/RandomUniform
# conv4a/random_uniform/sub
# conv4a/random_uniform/mul
# conv4a/random_uniform
# conv4a/kernel
# conv4a/kernel/Assign
# conv4a/kernel/read
# conv4a/Const
# conv4a/bias
# conv4a/bias/Assign
# conv4a/bias/read
# conv4a/convolution/Shape
# conv4a/convolution/dilation_rate
# conv4a/convolution
# conv4a/Reshape/shape
# conv4a/Reshape
# conv4a/add
# conv4a/Relu
# conv4b/random_uniform/shape
# conv4b/random_uniform/min
# conv4b/random_uniform/max
# conv4b/random_uniform/RandomUniform
# conv4b/random_uniform/sub
# conv4b/random_uniform/mul
# conv4b/random_uniform
# conv4b/kernel
# conv4b/kernel/Assign
# conv4b/kernel/read
# conv4b/Const
# conv4b/bias
# conv4b/bias/Assign
# conv4b/bias/read
# conv4b/convolution/Shape
# conv4b/convolution/dilation_rate
# conv4b/convolution
# conv4b/Reshape/shape
# conv4b/Reshape
# conv4b/add
# conv4b/Relu
# pool4/MaxPool3D
# conv5a/random_uniform/shape
# conv5a/random_uniform/min
# conv5a/random_uniform/max
# conv5a/random_uniform/RandomUniform
# conv5a/random_uniform/sub
# conv5a/random_uniform/mul
# conv5a/random_uniform
# conv5a/kernel
# conv5a/kernel/Assign
# conv5a/kernel/read
# conv5a/Const
# conv5a/bias
# conv5a/bias/Assign
# conv5a/bias/read
# conv5a/convolution/Shape
# conv5a/convolution/dilation_rate
# conv5a/convolution
# conv5a/Reshape/shape
# conv5a/Reshape
# conv5a/add
# conv5a/Relu
# conv5b/random_uniform/shape
# conv5b/random_uniform/min
# conv5b/random_uniform/max
# conv5b/random_uniform/RandomUniform
# conv5b/random_uniform/sub
# conv5b/random_uniform/mul
# conv5b/random_uniform
# conv5b/kernel
# conv5b/kernel/Assign
# conv5b/kernel/read
# conv5b/Const
# conv5b/bias
# conv5b/bias/Assign
# conv5b/bias/read
# conv5b/convolution/Shape
# conv5b/convolution/dilation_rate
# conv5b/convolution
# conv5b/Reshape/shape
# conv5b/Reshape
# conv5b/add
# conv5b/Relu
# zeropad5/Pad/paddings
# zeropad5/Pad
# pool5/MaxPool3D
# flatten_1/Shape
# flatten_1/strided_slice/stack
# flatten_1/strided_slice/stack_1
# flatten_1/strided_slice/stack_2
# flatten_1/strided_slice
# flatten_1/Const
# flatten_1/Prod
# flatten_1/stack/0
# flatten_1/stack
# flatten_1/Reshape
# fc6/random_uniform/shape
# fc6/random_uniform/min
# fc6/random_uniform/max
# fc6/random_uniform/RandomUniform
# fc6/random_uniform/sub
# fc6/random_uniform/mul
# fc6/random_uniform
# fc6/kernel
# fc6/kernel/Assign
# fc6/kernel/read
# fc6/Const
# fc6/bias
# fc6/bias/Assign
# fc6/bias/read
# fc6/MatMul
# fc6/BiasAdd
# fc6/Relu
# dropout_1/keras_learning_phase
# dropout_1/cond/Switch
# dropout_1/cond/switch_t
# dropout_1/cond/switch_f
# dropout_1/cond/pred_id
# dropout_1/cond/mul/y
# dropout_1/cond/mul/Switch
# dropout_1/cond/mul
# dropout_1/cond/dropout/keep_prob
# dropout_1/cond/dropout/Shape
# dropout_1/cond/dropout/random_uniform/min
# dropout_1/cond/dropout/random_uniform/max
# dropout_1/cond/dropout/random_uniform/RandomUniform
# dropout_1/cond/dropout/random_uniform/sub
# dropout_1/cond/dropout/random_uniform/mul
# dropout_1/cond/dropout/random_uniform
# dropout_1/cond/dropout/add
# dropout_1/cond/dropout/Floor
# dropout_1/cond/dropout/div
# dropout_1/cond/dropout/mul
# dropout_1/cond/Switch_1
# dropout_1/cond/Merge
# fc7/random_uniform/shape
# fc7/random_uniform/min
# fc7/random_uniform/max
# fc7/random_uniform/RandomUniform
# fc7/random_uniform/sub
# fc7/random_uniform/mul
# fc7/random_uniform
# fc7/kernel
# fc7/kernel/Assign
# fc7/kernel/read
# fc7/Const
# fc7/bias
# fc7/bias/Assign
# fc7/bias/read
# fc7/MatMul
# fc7/BiasAdd
# fc7/Relu
# dropout_2/cond/Switch
# dropout_2/cond/switch_t
# dropout_2/cond/switch_f
# dropout_2/cond/pred_id
# dropout_2/cond/mul/y
# dropout_2/cond/mul/Switch
# dropout_2/cond/mul
# dropout_2/cond/dropout/keep_prob
# dropout_2/cond/dropout/Shape
# dropout_2/cond/dropout/random_uniform/min
# dropout_2/cond/dropout/random_uniform/max
# dropout_2/cond/dropout/random_uniform/RandomUniform
# dropout_2/cond/dropout/random_uniform/sub
# dropout_2/cond/dropout/random_uniform/mul
# dropout_2/cond/dropout/random_uniform
# dropout_2/cond/dropout/add
# dropout_2/cond/dropout/Floor
# dropout_2/cond/dropout/div
# dropout_2/cond/dropout/mul
# dropout_2/cond/Switch_1
# dropout_2/cond/Merge
# fc8/random_uniform/shape
# fc8/random_uniform/min
# fc8/random_uniform/max
# fc8/random_uniform/RandomUniform
# fc8/random_uniform/sub
# fc8/random_uniform/mul
# fc8/random_uniform
# fc8/kernel
# fc8/kernel/Assign
# fc8/kernel/read
# fc8/Const
# fc8/bias
# fc8/bias/Assign
# fc8/bias/read
# fc8/MatMul
# fc8/BiasAdd
# sequential_1/conv1/convolution/Shape
# sequential_1/conv1/convolution/dilation_rate
# sequential_1/conv1/convolution
# sequential_1/conv1/Reshape/shape
# sequential_1/conv1/Reshape
# sequential_1/conv1/add
# sequential_1/conv1/Relu
# sequential_1/pool1/MaxPool3D
# sequential_1/conv2/convolution/Shape
# sequential_1/conv2/convolution/dilation_rate
# sequential_1/conv2/convolution
# sequential_1/conv2/Reshape/shape
# sequential_1/conv2/Reshape
# sequential_1/conv2/add
# sequential_1/conv2/Relu
# sequential_1/pool2/MaxPool3D
# sequential_1/conv3a/convolution/Shape
# sequential_1/conv3a/convolution/dilation_rate
# sequential_1/conv3a/convolution
# sequential_1/conv3a/Reshape/shape
# sequential_1/conv3a/Reshape
# sequential_1/conv3a/add
# sequential_1/conv3a/Relu
# sequential_1/conv3b/convolution/Shape
# sequential_1/conv3b/convolution/dilation_rate
# sequential_1/conv3b/convolution
# sequential_1/conv3b/Reshape/shape
# sequential_1/conv3b/Reshape
# sequential_1/conv3b/add
# sequential_1/conv3b/Relu
# sequential_1/pool3/MaxPool3D
# sequential_1/conv4a/convolution/Shape
# sequential_1/conv4a/convolution/dilation_rate
# sequential_1/conv4a/convolution
# sequential_1/conv4a/Reshape/shape
# sequential_1/conv4a/Reshape
# sequential_1/conv4a/add
# sequential_1/conv4a/Relu
# sequential_1/conv4b/convolution/Shape
# sequential_1/conv4b/convolution/dilation_rate
# sequential_1/conv4b/convolution
# sequential_1/conv4b/Reshape/shape
# sequential_1/conv4b/Reshape
# sequential_1/conv4b/add
# sequential_1/conv4b/Relu
# sequential_1/pool4/MaxPool3D
# sequential_1/conv5a/convolution/Shape
# sequential_1/conv5a/convolution/dilation_rate
# sequential_1/conv5a/convolution
# sequential_1/conv5a/Reshape/shape
# sequential_1/conv5a/Reshape
# sequential_1/conv5a/add
# sequential_1/conv5a/Relu
# sequential_1/conv5b/convolution/Shape
# sequential_1/conv5b/convolution/dilation_rate
# sequential_1/conv5b/convolution
# sequential_1/conv5b/Reshape/shape
# sequential_1/conv5b/Reshape
# sequential_1/conv5b/add
# sequential_1/conv5b/Relu
# sequential_1/zeropad5/Pad/paddings
# sequential_1/zeropad5/Pad
# sequential_1/pool5/MaxPool3D
# sequential_1/flatten_1/Shape
# sequential_1/flatten_1/strided_slice/stack
# sequential_1/flatten_1/strided_slice/stack_1
# sequential_1/flatten_1/strided_slice/stack_2
# sequential_1/flatten_1/strided_slice
# sequential_1/flatten_1/Const
# sequential_1/flatten_1/Prod
# sequential_1/flatten_1/stack/0
# sequential_1/flatten_1/stack
# sequential_1/flatten_1/Reshape
# sequential_1/fc6/MatMul
# sequential_1/fc6/BiasAdd
# sequential_1/fc6/Relu
# sequential_1/dropout_1/cond/Switch
# sequential_1/dropout_1/cond/switch_t
# sequential_1/dropout_1/cond/switch_f
# sequential_1/dropout_1/cond/pred_id
# sequential_1/dropout_1/cond/mul/y
# sequential_1/dropout_1/cond/mul/Switch
# sequential_1/dropout_1/cond/mul
# sequential_1/dropout_1/cond/dropout/keep_prob
# sequential_1/dropout_1/cond/dropout/Shape
# sequential_1/dropout_1/cond/dropout/random_uniform/min
# sequential_1/dropout_1/cond/dropout/random_uniform/max
# sequential_1/dropout_1/cond/dropout/random_uniform/RandomUniform
# sequential_1/dropout_1/cond/dropout/random_uniform/sub
# sequential_1/dropout_1/cond/dropout/random_uniform/mul
# sequential_1/dropout_1/cond/dropout/random_uniform
# sequential_1/dropout_1/cond/dropout/add
# sequential_1/dropout_1/cond/dropout/Floor
# sequential_1/dropout_1/cond/dropout/div
# sequential_1/dropout_1/cond/dropout/mul
# sequential_1/dropout_1/cond/Switch_1
# sequential_1/dropout_1/cond/Merge
# sequential_1/fc7/MatMul
# sequential_1/fc7/BiasAdd
# sequential_1/fc7/Relu
# sequential_1/dropout_2/cond/Switch
# sequential_1/dropout_2/cond/switch_t
# sequential_1/dropout_2/cond/switch_f
# sequential_1/dropout_2/cond/pred_id
# sequential_1/dropout_2/cond/mul/y
# sequential_1/dropout_2/cond/mul/Switch
# sequential_1/dropout_2/cond/mul
# sequential_1/dropout_2/cond/dropout/keep_prob
# sequential_1/dropout_2/cond/dropout/Shape
# sequential_1/dropout_2/cond/dropout/random_uniform/min
# sequential_1/dropout_2/cond/dropout/random_uniform/max
# sequential_1/dropout_2/cond/dropout/random_uniform/RandomUniform
# sequential_1/dropout_2/cond/dropout/random_uniform/sub
# sequential_1/dropout_2/cond/dropout/random_uniform/mul
# sequential_1/dropout_2/cond/dropout/random_uniform
# sequential_1/dropout_2/cond/dropout/add
# sequential_1/dropout_2/cond/dropout/Floor
# sequential_1/dropout_2/cond/dropout/div
# sequential_1/dropout_2/cond/dropout/mul
# sequential_1/dropout_2/cond/Switch_1
# sequential_1/dropout_2/cond/Merge
# sequential_1/fc8/MatMul
# sequential_1/fc8/BiasAdd
# Softmax
# ArgMax/dimension
# ArgMax
# Equal
# Cast
# Const
# Mean
# init
# save/Const
# save/SaveV2/tensor_names
# save/SaveV2/shape_and_slices
# save/SaveV2
# save/control_dependency
# save/RestoreV2/tensor_names
# save/RestoreV2/shape_and_slices
# save/RestoreV2
# save/Assign
# save/RestoreV2_1/tensor_names
# save/RestoreV2_1/shape_and_slices
# save/RestoreV2_1
# save/Assign_1
# save/RestoreV2_2/tensor_names
# save/RestoreV2_2/shape_and_slices
# save/RestoreV2_2
# save/Assign_2
# save/RestoreV2_3/tensor_names
# save/RestoreV2_3/shape_and_slices
# save/RestoreV2_3
# save/Assign_3
# save/RestoreV2_4/tensor_names
# save/RestoreV2_4/shape_and_slices
# save/RestoreV2_4
# save/Assign_4
# save/RestoreV2_5/tensor_names
# save/RestoreV2_5/shape_and_slices
# save/RestoreV2_5
# save/Assign_5
# save/RestoreV2_6/tensor_names
# save/RestoreV2_6/shape_and_slices
# save/RestoreV2_6
# save/Assign_6
# save/RestoreV2_7/tensor_names
# save/RestoreV2_7/shape_and_slices
# save/RestoreV2_7
# save/Assign_7
# save/RestoreV2_8/tensor_names
# save/RestoreV2_8/shape_and_slices
# save/RestoreV2_8
# save/Assign_8
# save/RestoreV2_9/tensor_names
# save/RestoreV2_9/shape_and_slices
# save/RestoreV2_9
# save/Assign_9
# save/RestoreV2_10/tensor_names
# save/RestoreV2_10/shape_and_slices
# save/RestoreV2_10
# save/Assign_10
# save/RestoreV2_11/tensor_names
# save/RestoreV2_11/shape_and_slices
# save/RestoreV2_11
# save/Assign_11
# save/RestoreV2_12/tensor_names
# save/RestoreV2_12/shape_and_slices
# save/RestoreV2_12
# save/Assign_12
# save/RestoreV2_13/tensor_names
# save/RestoreV2_13/shape_and_slices
# save/RestoreV2_13
# save/Assign_13
# save/RestoreV2_14/tensor_names
# save/RestoreV2_14/shape_and_slices
# save/RestoreV2_14
# save/Assign_14
# save/RestoreV2_15/tensor_names
# save/RestoreV2_15/shape_and_slices
# save/RestoreV2_15
# save/Assign_15
# save/RestoreV2_16/tensor_names
# save/RestoreV2_16/shape_and_slices
# save/RestoreV2_16
# save/Assign_16
# save/RestoreV2_17/tensor_names
# save/RestoreV2_17/shape_and_slices
# save/RestoreV2_17
# save/Assign_17
# save/RestoreV2_18/tensor_names
# save/RestoreV2_18/shape_and_slices
# save/RestoreV2_18
# save/Assign_18
# save/RestoreV2_19/tensor_names
# save/RestoreV2_19/shape_and_slices
# save/RestoreV2_19
# save/Assign_19
# save/RestoreV2_20/tensor_names
# save/RestoreV2_20/shape_and_slices
# save/RestoreV2_20
# save/Assign_20
# save/RestoreV2_21/tensor_names
# save/RestoreV2_21/shape_and_slices
# save/RestoreV2_21
# save/Assign_21
# save/restore_all

# %%
print(tf.contrib.graph_editor.get_tensors(tf.get_default_graph()))
# Out:
# [<tf.Tensor 'x:0' shape=(?, 16, 112, 112, 3) dtype=float32>, <tf.Tensor 'y_true:0' shape=(?, 101) dtype=float32>, <tf.Tensor 'y_true_cls:0' shape=(?,) dtype=int64>, <tf.Tensor 'conv1_input:0' shape=(?, 16, 112, 112, 3) dtype=float32>, <tf.Tensor 'conv1/random_uniform/shape:0' shape=(5,) dtype=int32>, <tf.Tensor 'conv1/random_uniform/min:0' shape=() dtype=float32>, <tf.Tensor 'conv1/random_uniform/max:0' shape=() dtype=float32>, <tf.Tensor 'conv1/random_uniform/RandomUniform:0' shape=(3, 3, 3, 3, 64) dtype=float32>, <tf.Tensor 'conv1/random_uniform/sub:0' shape=() dtype=float32>, <tf.Tensor 'conv1/random_uniform/mul:0' shape=(3, 3, 3, 3, 64) dtype=float32>, <tf.Tensor 'conv1/random_uniform:0' shape=(3, 3, 3, 3, 64) dtype=float32>, <tf.Tensor 'conv1/kernel:0' shape=(3, 3, 3, 3, 64) dtype=float32_ref>, <tf.Tensor 'conv1/kernel/Assign:0' shape=(3, 3, 3, 3, 64) dtype=float32_ref>, <tf.Tensor 'conv1/kernel/read:0' shape=(3, 3, 3, 3, 64) dtype=float32>, <tf.Tensor 'conv1/Const:0' shape=(64,) dtype=float32>, <tf.Tensor 'conv1/bias:0' shape=(64,) dtype=float32_ref>, <tf.Tensor 'conv1/bias/Assign:0' shape=(64,) dtype=float32_ref>, <tf.Tensor 'conv1/bias/read:0' shape=(64,) dtype=float32>, <tf.Tensor 'conv1/convolution/Shape:0' shape=(5,) dtype=int32>, <tf.Tensor 'conv1/convolution/dilation_rate:0' shape=(3,) dtype=int32>, <tf.Tensor 'conv1/convolution:0' shape=(?, 16, 112, 112, 64) dtype=float32>, <tf.Tensor 'conv1/Reshape/shape:0' shape=(4,) dtype=int32>, <tf.Tensor 'conv1/Reshape:0' shape=(1, 1, 1, 64) dtype=float32>, <tf.Tensor 'conv1/add:0' shape=(?, 16, 112, 112, 64) dtype=float32>, <tf.Tensor 'conv1/Relu:0' shape=(?, 16, 112, 112, 64) dtype=float32>, <tf.Tensor 'pool1/MaxPool3D:0' shape=(?, 16, 56, 56, 64) dtype=float32>, <tf.Tensor 'conv2/random_uniform/shape:0' shape=(5,) dtype=int32>, <tf.Tensor 'conv2/random_uniform/min:0' shape=() dtype=float32>, <tf.Tensor 'conv2/random_uniform/max:0' shape=() dtype=float32>, <tf.Tensor 'conv2/random_uniform/RandomUniform:0' shape=(3, 3, 3, 64, 128) dtype=float32>, <tf.Tensor 'conv2/random_uniform/sub:0' shape=() dtype=float32>, <tf.Tensor 'conv2/random_uniform/mul:0' shape=(3, 3, 3, 64, 128) dtype=float32>, <tf.Tensor 'conv2/random_uniform:0' shape=(3, 3, 3, 64, 128) dtype=float32>, <tf.Tensor 'conv2/kernel:0' shape=(3, 3, 3, 64, 128) dtype=float32_ref>, <tf.Tensor 'conv2/kernel/Assign:0' shape=(3, 3, 3, 64, 128) dtype=float32_ref>, <tf.Tensor 'conv2/kernel/read:0' shape=(3, 3, 3, 64, 128) dtype=float32>, <tf.Tensor 'conv2/Const:0' shape=(128,) dtype=float32>, <tf.Tensor 'conv2/bias:0' shape=(128,) dtype=float32_ref>, <tf.Tensor 'conv2/bias/Assign:0' shape=(128,) dtype=float32_ref>, <tf.Tensor 'conv2/bias/read:0' shape=(128,) dtype=float32>, <tf.Tensor 'conv2/convolution/Shape:0' shape=(5,) dtype=int32>, <tf.Tensor 'conv2/convolution/dilation_rate:0' shape=(3,) dtype=int32>, <tf.Tensor 'conv2/convolution:0' shape=(?, 16, 56, 56, 128) dtype=float32>, <tf.Tensor 'conv2/Reshape/shape:0' shape=(4,) dtype=int32>, <tf.Tensor 'conv2/Reshape:0' shape=(1, 1, 1, 128) dtype=float32>, <tf.Tensor 'conv2/add:0' shape=(?, 16, 56, 56, 128) dtype=float32>, <tf.Tensor 'conv2/Relu:0' shape=(?, 16, 56, 56, 128) dtype=float32>, <tf.Tensor 'pool2/MaxPool3D:0' shape=(?, 8, 28, 28, 128) dtype=float32>, <tf.Tensor 'conv3a/random_uniform/shape:0' shape=(5,) dtype=int32>, <tf.Tensor 'conv3a/random_uniform/min:0' shape=() dtype=float32>, <tf.Tensor 'conv3a/random_uniform/max:0' shape=() dtype=float32>, <tf.Tensor 'conv3a/random_uniform/RandomUniform:0' shape=(3, 3, 3, 128, 256) dtype=float32>, <tf.Tensor 'conv3a/random_uniform/sub:0' shape=() dtype=float32>, <tf.Tensor 'conv3a/random_uniform/mul:0' shape=(3, 3, 3, 128, 256) dtype=float32>, <tf.Tensor 'conv3a/random_uniform:0' shape=(3, 3, 3, 128, 256) dtype=float32>, <tf.Tensor 'conv3a/kernel:0' shape=(3, 3, 3, 128, 256) dtype=float32_ref>, <tf.Tensor 'conv3a/kernel/Assign:0' shape=(3, 3, 3, 128, 256) dtype=float32_ref>, <tf.Tensor 'conv3a/kernel/read:0' shape=(3, 3,  ...

# %%
print(tf.get_default_graph().as_graph_def())
# Out:
# node {
#   name: "x"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "y_true"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "y_true_cls"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT64
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "conv1_input"
#   op: "Placeholder"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#       }
#     }
#   }
# }
# node {
#   name: "conv1/random_uniform/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 5
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\003\000\000\000\003\000\000\000@\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv1/random_uniform/min"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -0.09975093603134155
#       }
#     }
#   }
# }
# node {
#   name: "conv1/random_uniform/max"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.09975093603134155
#       }
#     }
#   }
# }
# node {
#   name: "conv1/random_uniform/RandomUniform"
#   op: "RandomUniform"
#   input: "conv1/random_uniform/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "seed"
#     value {
#       i: 3
#     }
#   }
#   attr {
#     key: "seed2"
#     value {
#       i: 4686059
#     }
#   }
# }
# node {
#   name: "conv1/random_uniform/sub"
#   op: "Sub"
#   input: "conv1/random_uniform/max"
#   input: "conv1/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv1/random_uniform/mul"
#   op: "Mul"
#   input: "conv1/random_uniform/RandomUniform"
#   input: "conv1/random_uniform/sub"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv1/random_uniform"
#   op: "Add"
#   input: "conv1/random_uniform/mul"
#   input: "conv1/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv1/kernel"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 64
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv1/kernel/Assign"
#   op: "Assign"
#   input: "conv1/kernel"
#   input: "conv1/random_uniform"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv1/kernel"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "conv1/kernel/read"
#   op: "Identity"
#   input: "conv1/kernel"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv1/kernel"
#       }
#     }
#   }
# }
# node {
#   name: "conv1/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 64
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv1/bias"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 64
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv1/bias/Assign"
#   op: "Assign"
#   input: "conv1/bias"
#   input: "conv1/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv1/bias"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "conv1/bias/read"
#   op: "Identity"
#   input: "conv1/bias"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv1/bias"
#       }
#     }
#   }
# }
# node {
#   name: "conv1/convolution/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 5
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\003\000\000\000\003\000\000\000@\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv1/convolution/dilation_rate"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 3
#           }
#         }
#         tensor_content: "\001\000\000\000\001\000\000\000\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv1/convolution"
#   op: "Conv3D"
#   input: "conv1_input"
#   input: "conv1/kernel/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
# }
# node {
#   name: "conv1/Reshape/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 4
#           }
#         }
#         tensor_content: "\001\000\000\000\001\000\000\000\001\000\000\000@\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv1/Reshape"
#   op: "Reshape"
#   input: "conv1/bias/read"
#   input: "conv1/Reshape/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "conv1/add"
#   op: "Add"
#   input: "conv1/convolution"
#   input: "conv1/Reshape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv1/Relu"
#   op: "Relu"
#   input: "conv1/add"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "pool1/MaxPool3D"
#   op: "MaxPool3D"
#   input: "conv1/Relu"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "ksize"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 2
#         i: 2
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "VALID"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 2
#         i: 2
#         i: 1
#       }
#     }
#   }
# }
# node {
#   name: "conv2/random_uniform/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 5
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\003\000\000\000@\000\000\000\200\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv2/random_uniform/min"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -0.0589255653321743
#       }
#     }
#   }
# }
# node {
#   name: "conv2/random_uniform/max"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.0589255653321743
#       }
#     }
#   }
# }
# node {
#   name: "conv2/random_uniform/RandomUniform"
#   op: "RandomUniform"
#   input: "conv2/random_uniform/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "seed"
#     value {
#       i: 3
#     }
#   }
#   attr {
#     key: "seed2"
#     value {
#       i: 6762380
#     }
#   }
# }
# node {
#   name: "conv2/random_uniform/sub"
#   op: "Sub"
#   input: "conv2/random_uniform/max"
#   input: "conv2/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv2/random_uniform/mul"
#   op: "Mul"
#   input: "conv2/random_uniform/RandomUniform"
#   input: "conv2/random_uniform/sub"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv2/random_uniform"
#   op: "Add"
#   input: "conv2/random_uniform/mul"
#   input: "conv2/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv2/kernel"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 64
#         }
#         dim {
#           size: 128
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2/kernel/Assign"
#   op: "Assign"
#   input: "conv2/kernel"
#   input: "conv2/random_uniform"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2/kernel"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "conv2/kernel/read"
#   op: "Identity"
#   input: "conv2/kernel"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2/kernel"
#       }
#     }
#   }
# }
# node {
#   name: "conv2/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 128
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv2/bias"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 128
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv2/bias/Assign"
#   op: "Assign"
#   input: "conv2/bias"
#   input: "conv2/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2/bias"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "conv2/bias/read"
#   op: "Identity"
#   input: "conv2/bias"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv2/bias"
#       }
#     }
#   }
# }
# node {
#   name: "conv2/convolution/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 5
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\003\000\000\000@\000\000\000\200\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv2/convolution/dilation_rate"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 3
#           }
#         }
#         tensor_content: "\001\000\000\000\001\000\000\000\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv2/convolution"
#   op: "Conv3D"
#   input: "pool1/MaxPool3D"
#   input: "conv2/kernel/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
# }
# node {
#   name: "conv2/Reshape/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 4
#           }
#         }
#         tensor_content: "\001\000\000\000\001\000\000\000\001\000\000\000\200\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv2/Reshape"
#   op: "Reshape"
#   input: "conv2/bias/read"
#   input: "conv2/Reshape/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "conv2/add"
#   op: "Add"
#   input: "conv2/convolution"
#   input: "conv2/Reshape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv2/Relu"
#   op: "Relu"
#   input: "conv2/add"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "pool2/MaxPool3D"
#   op: "MaxPool3D"
#   input: "conv2/Relu"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "ksize"
#     value {
#       list {
#         i: 1
#         i: 2
#         i: 2
#         i: 2
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "VALID"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 2
#         i: 2
#         i: 2
#         i: 1
#       }
#     }
#   }
# }
# node {
#   name: "conv3a/random_uniform/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 5
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\003\000\000\000\200\000\000\000\000\001\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv3a/random_uniform/min"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -0.0416666679084301
#       }
#     }
#   }
# }
# node {
#   name: "conv3a/random_uniform/max"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.0416666679084301
#       }
#     }
#   }
# }
# node {
#   name: "conv3a/random_uniform/RandomUniform"
#   op: "RandomUniform"
#   input: "conv3a/random_uniform/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "seed"
#     value {
#       i: 3
#     }
#   }
#   attr {
#     key: "seed2"
#     value {
#       i: 491263
#     }
#   }
# }
# node {
#   name: "conv3a/random_uniform/sub"
#   op: "Sub"
#   input: "conv3a/random_uniform/max"
#   input: "conv3a/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv3a/random_uniform/mul"
#   op: "Mul"
#   input: "conv3a/random_uniform/RandomUniform"
#   input: "conv3a/random_uniform/sub"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv3a/random_uniform"
#   op: "Add"
#   input: "conv3a/random_uniform/mul"
#   input: "conv3a/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv3a/kernel"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 128
#         }
#         dim {
#           size: 256
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv3a/kernel/Assign"
#   op: "Assign"
#   input: "conv3a/kernel"
#   input: "conv3a/random_uniform"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv3a/kernel"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "conv3a/kernel/read"
#   op: "Identity"
#   input: "conv3a/kernel"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv3a/kernel"
#       }
#     }
#   }
# }
# node {
#   name: "conv3a/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 256
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv3a/bias"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 256
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv3a/bias/Assign"
#   op: "Assign"
#   input: "conv3a/bias"
#   input: "conv3a/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv3a/bias"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "conv3a/bias/read"
#   op: "Identity"
#   input: "conv3a/bias"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv3a/bias"
#       }
#     }
#   }
# }
# node {
#   name: "conv3a/convolution/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 5
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\003\000\000\000\200\000\000\000\000\001\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv3a/convolution/dilation_rate"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 3
#           }
#         }
#         tensor_content: "\001\000\000\000\001\000\000\000\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv3a/convolution"
#   op: "Conv3D"
#   input: "pool2/MaxPool3D"
#   input: "conv3a/kernel/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
# }
# node {
#   name: "conv3a/Reshape/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 4
#           }
#         }
#         tensor_content: "\001\000\000\000\001\000\000\000\001\000\000\000\000\001\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv3a/Reshape"
#   op: "Reshape"
#   input: "conv3a/bias/read"
#   input: "conv3a/Reshape/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "conv3a/add"
#   op: "Add"
#   input: "conv3a/convolution"
#   input: "conv3a/Reshape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv3a/Relu"
#   op: "Relu"
#   input: "conv3a/add"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv3b/random_uniform/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 5
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\003\000\000\000\000\001\000\000\000\001\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv3b/random_uniform/min"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -0.03608439117670059
#       }
#     }
#   }
# }
# node {
#   name: "conv3b/random_uniform/max"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.03608439117670059
#       }
#     }
#   }
# }
# node {
#   name: "conv3b/random_uniform/RandomUniform"
#   op: "RandomUniform"
#   input: "conv3b/random_uniform/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "seed"
#     value {
#       i: 3
#     }
#   }
#   attr {
#     key: "seed2"
#     value {
#       i: 6662859
#     }
#   }
# }
# node {
#   name: "conv3b/random_uniform/sub"
#   op: "Sub"
#   input: "conv3b/random_uniform/max"
#   input: "conv3b/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv3b/random_uniform/mul"
#   op: "Mul"
#   input: "conv3b/random_uniform/RandomUniform"
#   input: "conv3b/random_uniform/sub"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv3b/random_uniform"
#   op: "Add"
#   input: "conv3b/random_uniform/mul"
#   input: "conv3b/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv3b/kernel"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 256
#         }
#         dim {
#           size: 256
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv3b/kernel/Assign"
#   op: "Assign"
#   input: "conv3b/kernel"
#   input: "conv3b/random_uniform"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv3b/kernel"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "conv3b/kernel/read"
#   op: "Identity"
#   input: "conv3b/kernel"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv3b/kernel"
#       }
#     }
#   }
# }
# node {
#   name: "conv3b/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 256
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv3b/bias"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 256
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv3b/bias/Assign"
#   op: "Assign"
#   input: "conv3b/bias"
#   input: "conv3b/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv3b/bias"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "conv3b/bias/read"
#   op: "Identity"
#   input: "conv3b/bias"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv3b/bias"
#       }
#     }
#   }
# }
# node {
#   name: "conv3b/convolution/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 5
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\003\000\000\000\000\001\000\000\000\001\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv3b/convolution/dilation_rate"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 3
#           }
#         }
#         tensor_content: "\001\000\000\000\001\000\000\000\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv3b/convolution"
#   op: "Conv3D"
#   input: "conv3a/Relu"
#   input: "conv3b/kernel/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
# }
# node {
#   name: "conv3b/Reshape/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 4
#           }
#         }
#         tensor_content: "\001\000\000\000\001\000\000\000\001\000\000\000\000\001\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv3b/Reshape"
#   op: "Reshape"
#   input: "conv3b/bias/read"
#   input: "conv3b/Reshape/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "conv3b/add"
#   op: "Add"
#   input: "conv3b/convolution"
#   input: "conv3b/Reshape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv3b/Relu"
#   op: "Relu"
#   input: "conv3b/add"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "pool3/MaxPool3D"
#   op: "MaxPool3D"
#   input: "conv3b/Relu"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "ksize"
#     value {
#       list {
#         i: 1
#         i: 2
#         i: 2
#         i: 2
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "VALID"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 2
#         i: 2
#         i: 2
#         i: 1
#       }
#     }
#   }
# }
# node {
#   name: "conv4a/random_uniform/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 5
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\003\000\000\000\000\001\000\000\000\002\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv4a/random_uniform/min"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -0.02946278266608715
#       }
#     }
#   }
# }
# node {
#   name: "conv4a/random_uniform/max"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.02946278266608715
#       }
#     }
#   }
# }
# node {
#   name: "conv4a/random_uniform/RandomUniform"
#   op: "RandomUniform"
#   input: "conv4a/random_uniform/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "seed"
#     value {
#       i: 3
#     }
#   }
#   attr {
#     key: "seed2"
#     value {
#       i: 9554767
#     }
#   }
# }
# node {
#   name: "conv4a/random_uniform/sub"
#   op: "Sub"
#   input: "conv4a/random_uniform/max"
#   input: "conv4a/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv4a/random_uniform/mul"
#   op: "Mul"
#   input: "conv4a/random_uniform/RandomUniform"
#   input: "conv4a/random_uniform/sub"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv4a/random_uniform"
#   op: "Add"
#   input: "conv4a/random_uniform/mul"
#   input: "conv4a/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv4a/kernel"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 256
#         }
#         dim {
#           size: 512
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv4a/kernel/Assign"
#   op: "Assign"
#   input: "conv4a/kernel"
#   input: "conv4a/random_uniform"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv4a/kernel"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "conv4a/kernel/read"
#   op: "Identity"
#   input: "conv4a/kernel"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv4a/kernel"
#       }
#     }
#   }
# }
# node {
#   name: "conv4a/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 512
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv4a/bias"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 512
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv4a/bias/Assign"
#   op: "Assign"
#   input: "conv4a/bias"
#   input: "conv4a/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv4a/bias"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "conv4a/bias/read"
#   op: "Identity"
#   input: "conv4a/bias"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv4a/bias"
#       }
#     }
#   }
# }
# node {
#   name: "conv4a/convolution/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 5
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\003\000\000\000\000\001\000\000\000\002\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv4a/convolution/dilation_rate"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 3
#           }
#         }
#         tensor_content: "\001\000\000\000\001\000\000\000\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv4a/convolution"
#   op: "Conv3D"
#   input: "pool3/MaxPool3D"
#   input: "conv4a/kernel/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
# }
# node {
#   name: "conv4a/Reshape/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 4
#           }
#         }
#         tensor_content: "\001\000\000\000\001\000\000\000\001\000\000\000\000\002\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv4a/Reshape"
#   op: "Reshape"
#   input: "conv4a/bias/read"
#   input: "conv4a/Reshape/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "conv4a/add"
#   op: "Add"
#   input: "conv4a/convolution"
#   input: "conv4a/Reshape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv4a/Relu"
#   op: "Relu"
#   input: "conv4a/add"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv4b/random_uniform/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 5
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\003\000\000\000\000\002\000\000\000\002\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv4b/random_uniform/min"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -0.025515519082546234
#       }
#     }
#   }
# }
# node {
#   name: "conv4b/random_uniform/max"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.025515519082546234
#       }
#     }
#   }
# }
# node {
#   name: "conv4b/random_uniform/RandomUniform"
#   op: "RandomUniform"
#   input: "conv4b/random_uniform/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "seed"
#     value {
#       i: 3
#     }
#   }
#   attr {
#     key: "seed2"
#     value {
#       i: 7361472
#     }
#   }
# }
# node {
#   name: "conv4b/random_uniform/sub"
#   op: "Sub"
#   input: "conv4b/random_uniform/max"
#   input: "conv4b/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv4b/random_uniform/mul"
#   op: "Mul"
#   input: "conv4b/random_uniform/RandomUniform"
#   input: "conv4b/random_uniform/sub"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv4b/random_uniform"
#   op: "Add"
#   input: "conv4b/random_uniform/mul"
#   input: "conv4b/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv4b/kernel"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 512
#         }
#         dim {
#           size: 512
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv4b/kernel/Assign"
#   op: "Assign"
#   input: "conv4b/kernel"
#   input: "conv4b/random_uniform"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv4b/kernel"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "conv4b/kernel/read"
#   op: "Identity"
#   input: "conv4b/kernel"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv4b/kernel"
#       }
#     }
#   }
# }
# node {
#   name: "conv4b/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 512
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv4b/bias"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 512
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv4b/bias/Assign"
#   op: "Assign"
#   input: "conv4b/bias"
#   input: "conv4b/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv4b/bias"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "conv4b/bias/read"
#   op: "Identity"
#   input: "conv4b/bias"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv4b/bias"
#       }
#     }
#   }
# }
# node {
#   name: "conv4b/convolution/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 5
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\003\000\000\000\000\002\000\000\000\002\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv4b/convolution/dilation_rate"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 3
#           }
#         }
#         tensor_content: "\001\000\000\000\001\000\000\000\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv4b/convolution"
#   op: "Conv3D"
#   input: "conv4a/Relu"
#   input: "conv4b/kernel/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
# }
# node {
#   name: "conv4b/Reshape/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 4
#           }
#         }
#         tensor_content: "\001\000\000\000\001\000\000\000\001\000\000\000\000\002\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv4b/Reshape"
#   op: "Reshape"
#   input: "conv4b/bias/read"
#   input: "conv4b/Reshape/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "conv4b/add"
#   op: "Add"
#   input: "conv4b/convolution"
#   input: "conv4b/Reshape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv4b/Relu"
#   op: "Relu"
#   input: "conv4b/add"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "pool4/MaxPool3D"
#   op: "MaxPool3D"
#   input: "conv4b/Relu"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "ksize"
#     value {
#       list {
#         i: 1
#         i: 2
#         i: 2
#         i: 2
#         i: 1
#       }
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "VALID"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 2
#         i: 2
#         i: 2
#         i: 1
#       }
#     }
#   }
# }
# node {
#   name: "conv5a/random_uniform/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 5
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\003\000\000\000\000\002\000\000\000\002\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv5a/random_uniform/min"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: -0.025515519082546234
#       }
#     }
#   }
# }
# node {
#   name: "conv5a/random_uniform/max"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#         }
#         float_val: 0.025515519082546234
#       }
#     }
#   }
# }
# node {
#   name: "conv5a/random_uniform/RandomUniform"
#   op: "RandomUniform"
#   input: "conv5a/random_uniform/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "seed"
#     value {
#       i: 3
#     }
#   }
#   attr {
#     key: "seed2"
#     value {
#       i: 8802433
#     }
#   }
# }
# node {
#   name: "conv5a/random_uniform/sub"
#   op: "Sub"
#   input: "conv5a/random_uniform/max"
#   input: "conv5a/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv5a/random_uniform/mul"
#   op: "Mul"
#   input: "conv5a/random_uniform/RandomUniform"
#   input: "conv5a/random_uniform/sub"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv5a/random_uniform"
#   op: "Add"
#   input: "conv5a/random_uniform/mul"
#   input: "conv5a/random_uniform/min"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "conv5a/kernel"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 3
#         }
#         dim {
#           size: 512
#         }
#         dim {
#           size: 512
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv5a/kernel/Assign"
#   op: "Assign"
#   input: "conv5a/kernel"
#   input: "conv5a/random_uniform"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv5a/kernel"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "conv5a/kernel/read"
#   op: "Identity"
#   input: "conv5a/kernel"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv5a/kernel"
#       }
#     }
#   }
# }
# node {
#   name: "conv5a/Const"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 512
#           }
#         }
#         float_val: 0.0
#       }
#     }
#   }
# }
# node {
#   name: "conv5a/bias"
#   op: "VariableV2"
#   attr {
#     key: "container"
#     value {
#       s: ""
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size: 512
#         }
#       }
#     }
#   }
#   attr {
#     key: "shared_name"
#     value {
#       s: ""
#     }
#   }
# }
# node {
#   name: "conv5a/bias/Assign"
#   op: "Assign"
#   input: "conv5a/bias"
#   input: "conv5a/Const"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv5a/bias"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "conv5a/bias/read"
#   op: "Identity"
#   input: "conv5a/bias"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv5a/bias"
#       }
#     }
#   }
# }
# node {
#   name: "conv5a/convolution/Shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 5
#           }
#         }
#         tensor_content: "\003\000\000\000\003\000\000\000\003\000\000\000\000\002\000\000\000\002\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv5a/convolution/dilation_rate"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
#         tensor_shape {
#           dim {
#             size: 3
#           }
#         }
#         tensor_content: "\001\000\000\000\001\000\000\000\001\000\000\000"
#       }
#     }
#   }
# }
# node {
#   name: "conv5a/convolution"
#   op: "Conv3D"
#   input: "pool4/MaxPool3D"
#   input: "conv5a/kernel/read"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "padding"
#     value {
#       s: "SAME"
#     }
#   }
#   attr {
#     key: "strides"
#     value {
#       list {
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#         i: 1
#       }
#     }
#   }
# }
# node {
#   name: "conv5a/Reshape/shape"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_INT32
# ...
#   input: "save/RestoreV2_10/shape_and_slices"
#   attr {
#     key: "dtypes"
#     value {
#       list {
#         type: DT_FLOAT
#       }
#     }
#   }
# }
# node {
#   name: "save/Assign_10"
#   op: "Assign"
#   input: "conv4b/bias"
#   input: "save/RestoreV2_10"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv4b/bias"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_11/tensor_names"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: "conv4b/kernel"
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_11/shape_and_slices"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: ""
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_11"
#   op: "RestoreV2"
#   input: "save/Const"
#   input: "save/RestoreV2_11/tensor_names"
#   input: "save/RestoreV2_11/shape_and_slices"
#   attr {
#     key: "dtypes"
#     value {
#       list {
#         type: DT_FLOAT
#       }
#     }
#   }
# }
# node {
#   name: "save/Assign_11"
#   op: "Assign"
#   input: "conv4b/kernel"
#   input: "save/RestoreV2_11"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv4b/kernel"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_12/tensor_names"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: "conv5a/bias"
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_12/shape_and_slices"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: ""
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_12"
#   op: "RestoreV2"
#   input: "save/Const"
#   input: "save/RestoreV2_12/tensor_names"
#   input: "save/RestoreV2_12/shape_and_slices"
#   attr {
#     key: "dtypes"
#     value {
#       list {
#         type: DT_FLOAT
#       }
#     }
#   }
# }
# node {
#   name: "save/Assign_12"
#   op: "Assign"
#   input: "conv5a/bias"
#   input: "save/RestoreV2_12"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv5a/bias"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_13/tensor_names"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: "conv5a/kernel"
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_13/shape_and_slices"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: ""
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_13"
#   op: "RestoreV2"
#   input: "save/Const"
#   input: "save/RestoreV2_13/tensor_names"
#   input: "save/RestoreV2_13/shape_and_slices"
#   attr {
#     key: "dtypes"
#     value {
#       list {
#         type: DT_FLOAT
#       }
#     }
#   }
# }
# node {
#   name: "save/Assign_13"
#   op: "Assign"
#   input: "conv5a/kernel"
#   input: "save/RestoreV2_13"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv5a/kernel"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_14/tensor_names"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: "conv5b/bias"
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_14/shape_and_slices"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: ""
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_14"
#   op: "RestoreV2"
#   input: "save/Const"
#   input: "save/RestoreV2_14/tensor_names"
#   input: "save/RestoreV2_14/shape_and_slices"
#   attr {
#     key: "dtypes"
#     value {
#       list {
#         type: DT_FLOAT
#       }
#     }
#   }
# }
# node {
#   name: "save/Assign_14"
#   op: "Assign"
#   input: "conv5b/bias"
#   input: "save/RestoreV2_14"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv5b/bias"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_15/tensor_names"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: "conv5b/kernel"
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_15/shape_and_slices"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: ""
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_15"
#   op: "RestoreV2"
#   input: "save/Const"
#   input: "save/RestoreV2_15/tensor_names"
#   input: "save/RestoreV2_15/shape_and_slices"
#   attr {
#     key: "dtypes"
#     value {
#       list {
#         type: DT_FLOAT
#       }
#     }
#   }
# }
# node {
#   name: "save/Assign_15"
#   op: "Assign"
#   input: "conv5b/kernel"
#   input: "save/RestoreV2_15"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@conv5b/kernel"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_16/tensor_names"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: "fc6/bias"
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_16/shape_and_slices"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: ""
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_16"
#   op: "RestoreV2"
#   input: "save/Const"
#   input: "save/RestoreV2_16/tensor_names"
#   input: "save/RestoreV2_16/shape_and_slices"
#   attr {
#     key: "dtypes"
#     value {
#       list {
#         type: DT_FLOAT
#       }
#     }
#   }
# }
# node {
#   name: "save/Assign_16"
#   op: "Assign"
#   input: "fc6/bias"
#   input: "save/RestoreV2_16"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@fc6/bias"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_17/tensor_names"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: "fc6/kernel"
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_17/shape_and_slices"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: ""
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_17"
#   op: "RestoreV2"
#   input: "save/Const"
#   input: "save/RestoreV2_17/tensor_names"
#   input: "save/RestoreV2_17/shape_and_slices"
#   attr {
#     key: "dtypes"
#     value {
#       list {
#         type: DT_FLOAT
#       }
#     }
#   }
# }
# node {
#   name: "save/Assign_17"
#   op: "Assign"
#   input: "fc6/kernel"
#   input: "save/RestoreV2_17"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@fc6/kernel"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_18/tensor_names"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: "fc7/bias"
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_18/shape_and_slices"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: ""
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_18"
#   op: "RestoreV2"
#   input: "save/Const"
#   input: "save/RestoreV2_18/tensor_names"
#   input: "save/RestoreV2_18/shape_and_slices"
#   attr {
#     key: "dtypes"
#     value {
#       list {
#         type: DT_FLOAT
#       }
#     }
#   }
# }
# node {
#   name: "save/Assign_18"
#   op: "Assign"
#   input: "fc7/bias"
#   input: "save/RestoreV2_18"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@fc7/bias"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_19/tensor_names"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: "fc7/kernel"
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_19/shape_and_slices"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: ""
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_19"
#   op: "RestoreV2"
#   input: "save/Const"
#   input: "save/RestoreV2_19/tensor_names"
#   input: "save/RestoreV2_19/shape_and_slices"
#   attr {
#     key: "dtypes"
#     value {
#       list {
#         type: DT_FLOAT
#       }
#     }
#   }
# }
# node {
#   name: "save/Assign_19"
#   op: "Assign"
#   input: "fc7/kernel"
#   input: "save/RestoreV2_19"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@fc7/kernel"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_20/tensor_names"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: "fc8/bias"
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_20/shape_and_slices"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: ""
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_20"
#   op: "RestoreV2"
#   input: "save/Const"
#   input: "save/RestoreV2_20/tensor_names"
#   input: "save/RestoreV2_20/shape_and_slices"
#   attr {
#     key: "dtypes"
#     value {
#       list {
#         type: DT_FLOAT
#       }
#     }
#   }
# }
# node {
#   name: "save/Assign_20"
#   op: "Assign"
#   input: "fc8/bias"
#   input: "save/RestoreV2_20"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@fc8/bias"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_21/tensor_names"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: "fc8/kernel"
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_21/shape_and_slices"
#   op: "Const"
#   attr {
#     key: "dtype"
#     value {
#       type: DT_STRING
#     }
#   }
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_STRING
#         tensor_shape {
#           dim {
#             size: 1
#           }
#         }
#         string_val: ""
#       }
#     }
#   }
# }
# node {
#   name: "save/RestoreV2_21"
#   op: "RestoreV2"
#   input: "save/Const"
#   input: "save/RestoreV2_21/tensor_names"
#   input: "save/RestoreV2_21/shape_and_slices"
#   attr {
#     key: "dtypes"
#     value {
#       list {
#         type: DT_FLOAT
#       }
#     }
#   }
# }
# node {
#   name: "save/Assign_21"
#   op: "Assign"
#   input: "fc8/kernel"
#   input: "save/RestoreV2_21"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "_class"
#     value {
#       list {
#         s: "loc:@fc8/kernel"
#       }
#     }
#   }
#   attr {
#     key: "use_locking"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "validate_shape"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "save/restore_all"
#   op: "NoOp"
#   input: "^save/Assign"
#   input: "^save/Assign_1"
#   input: "^save/Assign_2"
#   input: "^save/Assign_3"
#   input: "^save/Assign_4"
#   input: "^save/Assign_5"
#   input: "^save/Assign_6"
#   input: "^save/Assign_7"
#   input: "^save/Assign_8"
#   input: "^save/Assign_9"
#   input: "^save/Assign_10"
#   input: "^save/Assign_11"
#   input: "^save/Assign_12"
#   input: "^save/Assign_13"
#   input: "^save/Assign_14"
#   input: "^save/Assign_15"
#   input: "^save/Assign_16"
#   input: "^save/Assign_17"
#   input: "^save/Assign_18"
#   input: "^save/Assign_19"
#   input: "^save/Assign_20"
#   input: "^save/Assign_21"
# }
# versions {
#   producer: 21
# }

# %%
j=1
batch_size_test=10
vid, test_labels_cls, next_batch_start, _ = ucf.read_vid_and_label('./UCF101_data_preparation/test.list',1,-1,16,112,normalisation=True)
test_labels=keras.utils.to_categorical(test_labels_cls, num_classes=nb_classes)

f_v = sess.graph.get_tensor_by_name('pool5/MaxPool3D:0')
print(f_v)
#f_v_val=sess.run([f_v,accuracy], feed_dict={'conv1_input:0':test_images[(batch_size_test*j):(batch_size_test*(j+1))],y_true:test_labels[(batch_size_test*j):(batch_size_test*(j+1))],x_image:test_images[(batch_size_test*j):(batch_size_test*(j+1))],'y_true_cls:0':test_labels_cls[(batch_size_test*j):(batch_size_test*(j+1))],K.learning_phase(): 0 })
f_v_val=sess.run([f_v], feed_dict={'conv1_input:0':vid,y_true:test_labels,x_image:vid,'y_true_cls:0':test_labels_cls,K.learning_phase(): 0 })
print(np.array(f_v_val).shape)
print(f_v_val)
# Out:
# Loading /nobackup/leopauly/UCF-101_video/ParallelBars/v_ParallelBars_g18_c02...
# (1, 16, 112, 112, 3)
# Tensor("pool5/MaxPool3D:0", shape=(?, 1, 4, 4, 512), dtype=float32)
# (1, 1, 1, 4, 4, 512)
# [array([[[[[ 0.02273332,  0.        ,  0.        , ...,  0.        ,
#             0.05069966,  0.0014639 ],
#           [ 0.01596038,  0.        ,  0.0007408 , ...,  0.00176701,
#             0.04851958,  0.01955871],
#           [ 0.00168746,  0.        ,  0.01932721, ...,  0.        ,
#             0.01813747,  0.04469587],
#           [ 0.00452264,  0.02779769,  0.0108511 , ...,  0.        ,
#             0.03751517,  0.01195011]],
#
#          [[ 0.03436964,  0.03084922,  0.        , ...,  0.01484608,
#             0.03481171,  0.00836052],
#           [ 0.05957279,  0.        ,  0.        , ...,  0.        ,
#             0.0219992 ,  0.01390005],
#           [ 0.04970333,  0.        ,  0.        , ...,  0.01334276,
#             0.00803524,  0.        ],
#           [ 0.01931756,  0.01321976,  0.00586023, ...,  0.00740931,
#             0.01826714,  0.        ]],
#
#          [[ 0.0017458 ,  0.02451255,  0.        , ...,  0.02155939,
#             0.02214797,  0.        ],
#           [ 0.00377207,  0.00304034,  0.        , ...,  0.00276735,
#             0.03395049,  0.        ],
#           [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#             0.0346228 ,  0.00231351],
#           [ 0.        ,  0.05375571,  0.        , ...,  0.02015701,
#             0.00677086,  0.        ]],
#
#          [[ 0.0266954 ,  0.007147  ,  0.        , ...,  0.        ,
#             0.02903414,  0.00239838],
#           [ 0.02552821,  0.00673348,  0.        , ...,  0.        ,
#             0.03458888,  0.        ],
#           [ 0.03806054,  0.        ,  0.        , ...,  0.        ,
#             0.04057975,  0.        ],
#           [ 0.00265772,  0.02729124,  0.0279137 , ...,  0.00587022,
#             0.        ,  0.00466531]]]]], dtype=float32)]

# %%
f_v_ = sess.graph.get_tensor_by_name('flatten_1/Reshape:0')
print(f_v_)
temp_=2
#f_v_val=sess.run([f_v,accuracy], feed_dict={'conv1_input:0':test_images[(batch_size_test*j):(batch_size_test*(j+1))],y_true:test_labels[(batch_size_test*j):(batch_size_test*(j+1))],x_image:test_images[(batch_size_test*j):(batch_size_test*(j+1))],'y_true_cls:0':test_labels_cls[(batch_size_test*j):(batch_size_test*(j+1))],K.learning_phase(): 0 })
f_v_val_=sess.run([f_v_], feed_dict={'conv1_input:0':vid,x_image:vid,K.learning_phase(): 0 })
print(np.array(f_v_val_).shape)
print(f_v_val_)

temp=np.mean((np.array(f_v_val_))-np.mean(np.array(f_v_val)))
# Out:
# Tensor("flatten_1/Reshape:0", shape=(?, ?), dtype=float32)
# (1, 1, 8192)
# [array([[ 0.02273332,  0.        ,  0.        , ...,  0.00587022,
#          0.        ,  0.00466531]], dtype=float32)]

# %%
feature=np.reshape(f_v_val_,(-1))
print(feature.shape)
# Out:
# (8192,)

# %%
print(int(temp))
# Out:
# 0
