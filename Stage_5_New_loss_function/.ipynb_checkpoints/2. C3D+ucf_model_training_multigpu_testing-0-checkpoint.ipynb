# %%
### 2. C3D+ucf_model_training_multigpu_training
# Author : @leopauly | cnlp@leeds.ac.uk <br>
# Description : Training the C3D model using UCF 101 action recognition dataset- Testing Phase

print('Started running the program..!',flush=True)
## Imports
from keras.models import Sequential
import random
import numpy as np
from PIL import Image
from os import listdir
from scipy.ndimage import imread
import keras
import tensorflow as tf
from tensorflow.python.client import device_lib
from keras import backend as K
import datetime
import time
import os 
from datetime import timedelta


# Custom scripts
import lscript as lsp
import modelling as md
#from DataSet.DataSet import DataSet
import dataset as dset
import ucf101_dataset as ucf

print('Loaded libraries...!!',flush=True)
# Out:
# Started running the program..!
# Using TensorFlow backend.
# Loaded libraries...!!

# %%
height=112 
width=112 
channel=3
cluster_length=16
nb_classes=101

lr_rate=.001
next_batch_start=0
batch_size=8
batch_size_test=16
total_train_videos=9991
memory_batch_size_train=50
memory_batch_size_test=3329
iterations= 10 # (int(total_train_videos/memory_batch_size_train)) #10001
custom_global_step=0
LOG_DIR='/nobackup/leopauly/logdir'
saved_path='/nobackup/leopauly/logdirk80_1'

print('Finished defining variables..!!',flush=True)
# Out:
# Finished defining variables..!!

# %%
## Defining placeholders in tf for images and targets
x_image = tf.placeholder(tf.float32, [None, 16,height,width,channel],name='x') 
y_true = tf.placeholder(tf.float32, [None, nb_classes],name='y_true')
y_true_cls = tf.placeholder(tf.int64, [None],name='y_true_cls')

model_keras = md.C3D_ucf101_training_model_tf(summary=False)
out=model_keras(x_image)
y_pred = tf.nn.softmax(out)
y_pred_cls = tf.argmax(out, dimension=1)
correct_prediction = tf.equal(y_pred_cls, y_true_cls)
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

print('Miscellenious items finished..!!',flush=True)
# Out:
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:392: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(64, (3, 3, 3), activation="relu", name="conv1", input_shape=(16, 112, ..., padding="same")`
#   input_shape=input_shape))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:394: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(pool_size=(1, 2, 2), strides=(1, 2, 2), name="pool1", padding="valid")`
#   border_mode='valid', name='pool1'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:397: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(128, (3, 3, 3), activation="relu", name="conv2", padding="same")`
#   border_mode='same', name='conv2'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:399: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), name="pool2", padding="valid")`
#   border_mode='valid', name='pool2'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:402: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(256, (3, 3, 3), activation="relu", name="conv3a", padding="same")`
#   border_mode='same', name='conv3a'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:404: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(256, (3, 3, 3), activation="relu", name="conv3b", padding="same")`
#   border_mode='same', name='conv3b'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:406: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), name="pool3", padding="valid")`
#   border_mode='valid', name='pool3'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:409: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(512, (3, 3, 3), activation="relu", name="conv4a", padding="same")`
#   border_mode='same', name='conv4a'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:411: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(512, (3, 3, 3), activation="relu", name="conv4b", padding="same")`
#   border_mode='same', name='conv4b'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:413: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), name="pool4", padding="valid")`
#   border_mode='valid', name='pool4'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:416: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(512, (3, 3, 3), activation="relu", name="conv5a", padding="same")`
#   border_mode='same', name='conv5a'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:418: UserWarning: Update your `Conv3D` call to the Keras 2 API: `Conv3D(512, (3, 3, 3), activation="relu", name="conv5b", padding="same")`
#   border_mode='same', name='conv5b'))
# /home/ufaserv1_f/cnlp/Seeing_to_Learn/Observation-Learning/Stage_5_New_loss_function/modelling.py:421: UserWarning: Update your `MaxPooling3D` call to the Keras 2 API: `MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), name="pool5", padding="valid")`
#   border_mode='valid', name='pool5'))
# Miscellenious items finished..!!

# %%
#### Training & testing
def testing(iterations,loops):
    #print(test_images.shape)
    #print(test_labels_cls)
    test_score=0
    for j in range(int(memory_batch_size_test/batch_size_test)-1):
        test_score_= sess.run([accuracy], feed_dict={x_image:test_images[(batch_size_test*j):(batch_size_test*(j+1))],y_true_cls:test_labels_cls[(batch_size_test*j):(batch_size_test*(j+1))],K.learning_phase(): 0 })
        #print('returned value',test_score_)
        print(test_score_)
        test_score=test_score+sum(test_score_)
    print('Test accuracy after iteration:',iterations,',loop:',loops,'is:',test_score/(j+1),flush=True)

# %%
## Loading Testing data
start_time = time.time()
test_images, test_labels_cls, next_batch_start, _ = ucf.read_vid_and_label('./UCF101_data_preparation/test.list',memory_batch_size_test,-1,16,112,normalisation=False)
end_time = time.time()
time_dif = end_time - start_time
print("Time usage for loading training dataset: " + str(timedelta(seconds=int(round(time_dif)))),flush=True)
test_labels=keras.utils.to_categorical(test_labels_cls, num_classes=nb_classes)
print('testing data loaded',flush=True)
# Out:
# Loading /nobackup/leopauly/UCF-101_video/CricketShot/v_CricketShot_g13_c06...
# Loading /nobackup/leopauly/UCF-101_video/PoleVault/v_PoleVault_g16_c07...
# Loading /nobackup/leopauly/UCF-101_video/TennisSwing/v_TennisSwing_g14_c03...
# Loading /nobackup/leopauly/UCF-101_video/BoxingSpeedBag/v_BoxingSpeedBag_g25_c02...
# Loading /nobackup/leopauly/UCF-101_video/FrisbeeCatch/v_FrisbeeCatch_g02_c02...
# Loading /nobackup/leopauly/UCF-101_video/JumpRope/v_JumpRope_g20_c03...
# Loading /nobackup/leopauly/UCF-101_video/BrushingTeeth/v_BrushingTeeth_g16_c04...
# Loading /nobackup/leopauly/UCF-101_video/BreastStroke/v_BreastStroke_g20_c02...
# Loading /nobackup/leopauly/UCF-101_video/Diving/v_Diving_g22_c02...
# Loading /nobackup/leopauly/UCF-101_video/Swing/v_Swing_g14_c01...
# Loading /nobackup/leopauly/UCF-101_video/PommelHorse/v_PommelHorse_g21_c01...
# Loading /nobackup/leopauly/UCF-101_video/JumpingJack/v_JumpingJack_g23_c04...
# Loading /nobackup/leopauly/UCF-101_video/BasketballDunk/v_BasketballDunk_g21_c01...
# Loading /nobackup/leopauly/UCF-101_video/Hammering/v_Hammering_g17_c03...
# Loading /nobackup/leopauly/UCF-101_video/PlayingDhol/v_PlayingDhol_g16_c01...
# Loading /nobackup/leopauly/UCF-101_video/CleanAndJerk/v_CleanAndJerk_g24_c03...
# Loading /nobackup/leopauly/UCF-101_video/ApplyLipstick/v_ApplyLipstick_g07_c04...
# Loading /nobackup/leopauly/UCF-101_video/CricketBowling/v_CricketBowling_g21_c02...
# Loading /nobackup/leopauly/UCF-101_video/PlayingPiano/v_PlayingPiano_g03_c03...
# Loading /nobackup/leopauly/UCF-101_video/SkyDiving/v_SkyDiving_g19_c04...
# Loading /nobackup/leopauly/UCF-101_video/CricketShot/v_CricketShot_g22_c01...
# Loading /nobackup/leopauly/UCF-101_video/Haircut/v_Haircut_g11_c05...
# Loading /nobackup/leopauly/UCF-101_video/PlayingFlute/v_PlayingFlute_g05_c02...
# Loading /nobackup/leopauly/UCF-101_video/BreastStroke/v_BreastStroke_g08_c03...
# Loading /nobackup/leopauly/UCF-101_video/Fencing/v_Fencing_g14_c03...
# Loading /nobackup/leopauly/UCF-101_video/BaseballPitch/v_BaseballPitch_g20_c04...
# Loading /nobackup/leopauly/UCF-101_video/Basketball/v_Basketball_g03_c03...
# Loading /nobackup/leopauly/UCF-101_video/Swing/v_Swing_g04_c02...
# Loading /nobackup/leopauly/UCF-101_video/IceDancing/v_IceDancing_g03_c02...
# Loading /nobackup/leopauly/UCF-101_video/BandMarching/v_BandMarching_g11_c01...
# Loading /nobackup/leopauly/UCF-101_video/Lunges/v_Lunges_g06_c07...
# Loading /nobackup/leopauly/UCF-101_video/ApplyLipstick/v_ApplyLipstick_g22_c06...
# Loading /nobackup/leopauly/UCF-101_video/Diving/v_Diving_g02_c02...
# Loading /nobackup/leopauly/UCF-101_video/MilitaryParade/v_MilitaryParade_g23_c01...
# Loading /nobackup/leopauly/UCF-101_video/LongJump/v_LongJump_g10_c02...
# Loading /nobackup/leopauly/UCF-101_video/FieldHockeyPenalty/v_FieldHockeyPenalty_g07_c03...
# Loading /nobackup/leopauly/UCF-101_video/FrontCrawl/v_FrontCrawl_g06_c01...
# Loading /nobackup/leopauly/UCF-101_video/Mixing/v_Mixing_g14_c04...
# Loading /nobackup/leopauly/UCF-101_video/YoYo/v_YoYo_g10_c02...
# Loading /nobackup/leopauly/UCF-101_video/ApplyLipstick/v_ApplyLipstick_g23_c03...
# Loading /nobackup/leopauly/UCF-101_video/BabyCrawling/v_BabyCrawling_g10_c04...
# Loading /nobackup/leopauly/UCF-101_video/BabyCrawling/v_BabyCrawling_g25_c03...
# Loading /nobackup/leopauly/UCF-101_video/PlayingSitar/v_PlayingSitar_g20_c07...
# Loading /nobackup/leopauly/UCF-101_video/RopeClimbing/v_RopeClimbing_g12_c02...
# Loading /nobackup/leopauly/UCF-101_video/ShavingBeard/v_ShavingBeard_g14_c04...
# Loading /nobackup/leopauly/UCF-101_video/MilitaryParade/v_MilitaryParade_g06_c04...
# Loading /nobackup/leopauly/UCF-101_video/PlayingPiano/v_PlayingPiano_g18_c02...
# Loading /nobackup/leopauly/UCF-101_video/SoccerPenalty/v_SoccerPenalty_g24_c04...
# Loading /nobackup/leopauly/UCF-101_video/RockClimbingIndoor/v_RockClimbingIndoor_g11_c02...
# Loading /nobackup/leopauly/UCF-101_video/Fencing/v_Fencing_g22_c03...
# Loading /nobackup/leopauly/UCF-101_video/CricketShot/v_CricketShot_g19_c03...
# Loading /nobackup/leopauly/UCF-101_video/PlayingDhol/v_PlayingDhol_g21_c07...
# Loading /nobackup/leopauly/UCF-101_video/Drumming/v_Drumming_g11_c06...
# Loading /nobackup/leopauly/UCF-101_video/WalkingWithDog/v_WalkingWithDog_g12_c01...
# Loading /nobackup/leopauly/UCF-101_video/HammerThrow/v_HammerThrow_g25_c03...
# Loading /nobackup/leopauly/UCF-101_video/Biking/v_Biking_g14_c01...
# Loading /nobackup/leopauly/UCF-101_video/UnevenBars/v_UnevenBars_g05_c02...
# Loading /nobackup/leopauly/UCF-101_video/Nunchucks/v_Nunchucks_g07_c01...
# Loading /nobackup/leopauly/UCF-101_video/CliffDiving/v_CliffDiving_g07_c02...
# Loading /nobackup/leopauly/UCF-101_video/SalsaSpin/v_SalsaSpin_g15_c03...
# Loading /nobackup/leopauly/UCF-101_video/PoleVault/v_PoleVault_g18_c05...
# Loading /nobackup/leopauly/UCF-101_video/TableTennisShot/v_TableTennisShot_g22_c01...
# Loading /nobackup/leopauly/UCF-101_video/Nunchucks/v_Nunchucks_g03_c06...
# Loading /nobackup/leopauly/UCF-101_video/WritingOnBoard/v_WritingOnBoard_g11_c03...
# Loading /nobackup/leopauly/UCF-101_video/ApplyEyeMakeup/v_ApplyEyeMakeup_
# Loading /nobackup/leopauly/UCF-101_video/BoxingPunchingBag/v_BoxingPunchingBag_g03_c06...
# Loading /nobackup/leopauly/UCF-101_video/Rowing/v_Rowing_g17_c07...
# Loading /nobackup/leopauly/UCF-101_video/Diving/v_Diving_g24_c06...
# Loading /nobackup/leopauly/UCF-101_video/BoxingPunchingBag/v_BoxingPunchingBag_g14_c05...
# Loading /nobackup/leopauly/UCF-101_video/PlayingViolin/v_PlayingViolin_g04_c02...
# Loading /nobackup/leopauly/UCF-101_video/PommelHorse/v_PommelHorse_g03_c02...

# %%
#### Start the session with logging placement.
init_op = tf.global_variables_initializer()
sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True, log_device_placement=False))
sess.run(init_op)

# Restore model weights from previously saved model

#saver = tf.train.import_meta_graph(os.path.join(saved_path,'activity_model_1.ckpt-43.meta'))
saver = tf.train.Saver()
saver.restore(sess, os.path.join(saved_path,'activity_model.ckpt-67'))
print("Model restored from file: %s" % saved_path,flush=True)

# %%
start_time = time.time()
testing(0,0)
end_time = time.time()
time_dif = end_time - start_time
print("Time taken for testing: " + str(timedelta(seconds=int(round(time_dif)))),flush=True)

# %%
#sess.close()

# %%
print([n.name for n in tf.get_default_graph().as_graph_def().node])

# %%
for op in tf.get_default_graph().get_operations():
    print(op.name)

# %%
print(tf.contrib.graph_editor.get_tensors(tf.get_default_graph()))

# %%
print(tf.get_default_graph().as_graph_def())

# %%
j=1
batch_size_test=10
vid, test_labels_cls, next_batch_start, _ = ucf.read_vid_and_label('./UCF101_data_preparation/test.list',1,-1,16,112,normalisation=False)
test_labels=keras.utils.to_categorical(test_labels_cls, num_classes=nb_classes)

f_v = sess.graph.get_tensor_by_name('pool5/MaxPool3D:0')
print(f_v)
#f_v_val=sess.run([f_v,accuracy], feed_dict={'conv1_input:0':test_images[(batch_size_test*j):(batch_size_test*(j+1))],y_true:test_labels[(batch_size_test*j):(batch_size_test*(j+1))],x_image:test_images[(batch_size_test*j):(batch_size_test*(j+1))],'y_true_cls:0':test_labels_cls[(batch_size_test*j):(batch_size_test*(j+1))],K.learning_phase(): 0 })
f_v_val=sess.run([f_v], feed_dict={'conv1_input:0':vid,y_true:test_labels,x_image:vid,'y_true_cls:0':test_labels_cls,K.learning_phase(): 0 })
print(np.array(f_v_val).shape)
print(f_v_val)

# %%
f_v_ = sess.graph.get_tensor_by_name('flatten_1/Reshape:0')
print(f_v_)
temp_=2
#f_v_val=sess.run([f_v,accuracy], feed_dict={'conv1_input:0':test_images[(batch_size_test*j):(batch_size_test*(j+1))],y_true:test_labels[(batch_size_test*j):(batch_size_test*(j+1))],x_image:test_images[(batch_size_test*j):(batch_size_test*(j+1))],'y_true_cls:0':test_labels_cls[(batch_size_test*j):(batch_size_test*(j+1))],K.learning_phase(): 0 })
f_v_val_=sess.run([f_v_], feed_dict={'conv1_input:0':vid,x_image:vid,K.learning_phase(): 0 })
print(np.array(f_v_val_).shape)
print(f_v_val_)

temp=np.mean((np.array(f_v_val_))-np.mean(np.array(f_v_val)))

# %%
feature=np.reshape(f_v_val_,(-1))
print(feature.shape)

# %%
print(int(temp))
